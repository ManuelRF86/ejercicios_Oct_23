# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: **Transfer Learning y Fine Tuning**

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en un repetir el ejercicio de construcción de un modelo de clasificación de paisajes pero usando un modelo preentrenado. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Ejercicio 0

# %% [markdown]
# Importa los paquetes y módulos que necesites a lo largo del notebook.

# %%
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns


from skimage.io import imread
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
# Out:
# WARNING:tensorflow:From c:\Users\edici\Online_Env\Curso_Online_DATA\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ### Objetivo del ejercicio
#
# Comparar una red convolucional hecha ad-hoc frente a los modelos preentrenados y ajustados con fine tuning y transfer learning. Para ello emplea el dataset de paisajes del conjunto de ejercicios de la unidad anterior.
#
#
# ### Se pide
#
# 1. Preparar los datos del modelo y las funciones de visualización, copia para ello todo lo que necesites de las soluciones del ejercicio de clasificación de paisajes de la unidad anterior.
#
# 2. Escoger entre uno de los modelos VGG-19, InceptionV3 y MobileNetV2 (todos en https://keras.io/api/applications/) (Se aconseja este último si no tenemos un ordenador muy potente). Si no te haces con estos puedes recurrir a la ResNetV50.
#
# 4. Hacer un transfer-learning con una cabeza de como mucho 2 capas densas ocultas y una de salida. Mostrar la evaluación contra test, el report de clasificación y la matriz de confusión.
#
# 5. Hacer un fine-tuning con la misma cabeza diseñada en el punto anterior. Mostrar la evaluación contra test, el report de clasificación y la matriz de confusión.
#
# 6. Comparar los resultados con los obtenidos con la red convolucional del ejercicio mencionado.
#
# EXTRA:
# - Repetir el transfer learning empleando aumentado de imágenes.

# %% [markdown]
# ### Funciones y preparación de datos (código replicado de la solución del ejercicio de la primera unidad)

# %%
### Carga de datos y preparación obtenidas del ejercicio de la unidad 1:
ROOT_PATH = './data/'
TRAIN_PATH = ROOT_PATH + "seg_train/"
TEST_PATH = ROOT_PATH + "seg_test/"

# %% [markdown]
# *Introducimos un parametro de control de la resolución, inicialmente a 32, pero que podamos tocar sin cambiar nada del resto del código para poder probar otras resoluciones*

# %%
IMG_WIDTH = IMG_HEIGHT = 75

# %%
def read_data(directorio, reshape_dim = (IMG_WIDTH,IMG_HEIGHT)):
    X = [] 
    y = []
    for folder in os.listdir(directorio):
        print(folder)
        if os.path.isdir('/'.join([directorio, folder])):
            for file in os.listdir('/'.join([directorio, folder])):

                image = imread('/'.join([directorio, folder, file]))
                image = cv2.resize(image, reshape_dim) # Redimensionamos las imágenes a 32x32

                X.append(image)
                y.append(folder)

    return np.array(X),np.array(y)

def show_images_batch(paisajes, names = [], n_cols = 5, size_scale = 2):
    n_rows = ((len(paisajes) - 1) // n_cols + 1)
    plt.figure(figsize=(n_cols * size_scale, n_rows * 1.1*size_scale))
    for index, paisaje in enumerate(paisajes):
        plt.subplot(n_rows, n_cols, index + 1)
        plt.imshow(paisaje, cmap = "Greys")
        plt.axis("off")
        if len(names):
            plt.title(names[index])

# %%
X_train,y_train = read_data(TRAIN_PATH)
X_test, y_test = read_data(TEST_PATH)
# Out:
# buildings
# forest
# glacier
# mountain
# sea
# street
# buildings
# forest
# glacier
# mountain
# sea
# street

# %%
indices = np.random.randint(0,len(X_train),20)
show_images_batch(X_train[indices], names = y_train[indices], n_cols = 5)

# %%
X_train = X_train/255
X_test = X_test/255

# %% [markdown]
# ### Seleccion del modelo a transferir y tunear

# %% [markdown]
# *Escogemos el modelo de [Inception V3](https://arxiv.org/abs/1512.00567) el que tiene las supercapas convolucionales para hacer transfer learning*

# %%
from keras.applications import InceptionV3

# %% [markdown]
# *Si investigas en la documentación del modelo verás que no puede admite resoluciones de entrada inferiores a 75x75*

# %% [markdown]
# ### Transfer Learning

# %% [markdown]
# *Para el transfer learning vamos a usar una cabeza con una única capa densa con tantas unidades como el aplanamiento de las imagenes, es decir dependiendo de la resolución con la que hayamos cargado las imágenes al principio así tendremos una cantidad u otra de unidades*

# %%
X_train.size
# Out:
# 236823750

# %% [markdown]
# *El train tiene un tamaño más que considerable para aplicar un Adam y eso vamos a hacer, en principio sin tocar nada más*

# %%
IMG_WIDTH = IMG_HEIGHT = 75
# Cargamos el modelo pre-entrenado
base_model = InceptionV3(include_top=False, weights='imagenet', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3))

# Congelamos sus capas
for layer in base_model.layers:
    layer.trainable = False


# Capa de flatenizado de la salida del modelo base
def prepare_model(base_model = base_model): # Lo creamos así para poder reinicializarlo en cada reentrenamiento en ejercicios posteriores
    x = keras.layers.Flatten()(base_model.output)
    
    # Tantas unidades como el flatten de la salida de Inception -> 5625 features
    x = keras.layers.Dense(2048, activation='relu')(x)
    x = keras.layers.Dropout(rate = 0.25)(x)

    # Capa final de salida con 6 neuronas (una por clase) y activación softmax
    x = keras.layers.Dense(6, activation='softmax')(x)
    
    model = keras.Model(base_model.input, x)
    model.compile(optimizer = "adam", loss = 'sparse_categorical_crossentropy', metrics = ['acc']) # sparse -> y es un array de escalares pero hay varias categorias, y un array de vectores
    return model
# Observamos la arquitectura del modelo
model= prepare_model()
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 75, 75, 3)]          0         []
#
#  conv2d_376 (Conv2D)         (None, 37, 37, 32)           864       ['input_5[0][0]']
#
#  batch_normalization_376 (B  (None, 37, 37, 32)           96        ['conv2d_376[0][0]']
#  atchNormalization)
#
#  activation_376 (Activation  (None, 37, 37, 32)           0         ['batch_normalization_376[0][0
#  )                                                                  ]']
#
#  conv2d_377 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_376[0][0]']
#
#  batch_normalization_377 (B  (None, 35, 35, 32)           96        ['conv2d_377[0][0]']
#  atchNormalization)
#
#  activation_377 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_377[0][0
#  )                                                                  ]']
#
#  conv2d_378 (Conv2D)         (None, 35, 35, 64)           18432     ['activation_377[0][0]']
#
#  batch_normalization_378 (B  (None, 35, 35, 64)           192       ['conv2d_378[0][0]']
#  atchNormalization)
#
#  activation_378 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_378[0][0
#  )                                                                  ]']
#
#  max_pooling2d_16 (MaxPooli  (None, 17, 17, 64)           0         ['activation_378[0][0]']
#  ng2D)
#
#  conv2d_379 (Conv2D)         (None, 17, 17, 80)           5120      ['max_pooling2d_16[0][0]']
#
#  batch_normalization_379 (B  (None, 17, 17, 80)           240       ['conv2d_379[0][0]']
#  atchNormalization)
#
#  activation_379 (Activation  (None, 17, 17, 80)           0         ['batch_normalization_379[0][0
#  )                                                                  ]']
#
#  conv2d_380 (Conv2D)         (None, 15, 15, 192)          138240    ['activation_379[0][0]']
#
#  batch_normalization_380 (B  (None, 15, 15, 192)          576       ['conv2d_380[0][0]']
#  atchNormalization)
#
#  activation_380 (Activation  (None, 15, 15, 192)          0         ['batch_normalization_380[0][0
#  )                                                                  ]']
#
#  max_pooling2d_17 (MaxPooli  (None, 7, 7, 192)            0         ['activation_380[0][0]']
#  ng2D)
#
#  conv2d_384 (Conv2D)         (None, 7, 7, 64)             12288     ['max_pooling2d_17[0][0]']
#
#  batch_normalization_384 (B  (None, 7, 7, 64)             192       ['conv2d_384[0][0]']
#  atchNormalization)
#
#  activation_384 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_384[0][0
#  )                                                                  ]']
#
#  conv2d_382 (Conv2D)         (None, 7, 7, 48)             9216      ['max_pooling2d_17[0][0]']
#
#  conv2d_385 (Conv2D)         (None, 7, 7, 96)             55296     ['activation_384[0][0]']
#
#  batch_normalization_382 (B  (None, 7, 7, 48)             144       ['conv2d_382[0][0]']
#  atchNormalization)
#
#  batch_normalization_385 (B  (None, 7, 7, 96)             288       ['conv2d_385[0][0]']
#  atchNormalization)
#
#  activation_382 (Activation  (None, 7, 7, 48)             0         ['batch_normalization_382[0][0
#  )                                                                  ]']
#
#  activation_385 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_385[0][0
#  )                                                                  ]']
#
#  average_pooling2d_36 (Aver  (None, 7, 7, 192)            0         ['max_pooling2d_17[0][0]']
#  agePooling2D)
#
#  conv2d_381 (Conv2D)         (None, 7, 7, 64)             12288     ['max_pooling2d_17[0][0]']
#
#  conv2d_383 (Conv2D)         (None, 7, 7, 64)             76800     ['activation_382[0][0]']
#
#  conv2d_386 (Conv2D)         (None, 7, 7, 96)             82944     ['activation_385[0][0]']
#
#  conv2d_387 (Conv2D)         (None, 7, 7, 32)             6144      ['average_pooling2d_36[0][0]']
#
#  batch_normalization_381 (B  (None, 7, 7, 64)             192       ['conv2d_381[0][0]']
#  atchNormalization)
#
#  batch_normalization_383 (B  (None, 7, 7, 64)             192       ['conv2d_383[0][0]']
#  atchNormalization)
#
#  batch_normalization_386 (B  (None, 7, 7, 96)             288       ['conv2d_386[0][0]']
#  atchNormalization)
#
#  batch_normalization_387 (B  (None, 7, 7, 32)             96        ['conv2d_387[0][0]']
#  atchNormalization)
#
#  activation_381 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_381[0][0
#  )                                                                  ]']
#
#  activation_383 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_383[0][0
#  )                                                                  ]']
#
#  activation_386 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_386[0][0
#  )                                                                  ]']
#
#  activation_387 (Activation  (None, 7, 7, 32)             0         ['batch_normalization_387[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 7, 7, 256)            0         ['activation_381[0][0]',
#                                                                      'activation_383[0][0]',
#                                                                      'activation_386[0][0]',
#                                                                      'activation_387[0][0]']
#
#  conv2d_391 (Conv2D)         (None, 7, 7, 64)             16384     ['mixed0[0][0]']
#
#  batch_normalization_391 (B  (None, 7, 7, 64)             192       ['conv2d_391[0][0]']
#  atchNormalization)
#
#  activation_391 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_391[0][0
#  )                                                                  ]']
#
#  conv2d_389 (Conv2D)         (None, 7, 7, 48)             12288     ['mixed0[0][0]']
#
#  conv2d_392 (Conv2D)         (None, 7, 7, 96)             55296     ['activation_391[0][0]']
#
#  batch_normalization_389 (B  (None, 7, 7, 48)             144       ['conv2d_389[0][0]']
#  atchNormalization)
#
#  batch_normalization_392 (B  (None, 7, 7, 96)             288       ['conv2d_392[0][0]']
#  atchNormalization)
#
#  activation_389 (Activation  (None, 7, 7, 48)             0         ['batch_normalization_389[0][0
#  )                                                                  ]']
#
#  activation_392 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_392[0][0
#  )                                                                  ]']
#
#  average_pooling2d_37 (Aver  (None, 7, 7, 256)            0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_388 (Conv2D)         (None, 7, 7, 64)             16384     ['mixed0[0][0]']
#
#  conv2d_390 (Conv2D)         (None, 7, 7, 64)             76800     ['activation_389[0][0]']
#
#  conv2d_393 (Conv2D)         (None, 7, 7, 96)             82944     ['activation_392[0][0]']
#
#  conv2d_394 (Conv2D)         (None, 7, 7, 64)             16384     ['average_pooling2d_37[0][0]']
#
#  batch_normalization_388 (B  (None, 7, 7, 64)             192       ['conv2d_388[0][0]']
#  atchNormalization)
#
#  batch_normalization_390 (B  (None, 7, 7, 64)             192       ['conv2d_390[0][0]']
#  atchNormalization)
#
#  batch_normalization_393 (B  (None, 7, 7, 96)             288       ['conv2d_393[0][0]']
#  atchNormalization)
#
#  batch_normalization_394 (B  (None, 7, 7, 64)             192       ['conv2d_394[0][0]']
#  atchNormalization)
#
#  activation_388 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_388[0][0
#  )                                                                  ]']
#
#  activation_390 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_390[0][0
#  )                                                                  ]']
#
#  activation_393 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_393[0][0
#  )                                                                  ]']
#
#  activation_394 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_394[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 7, 7, 288)            0         ['activation_388[0][0]',
#                                                                      'activation_390[0][0]',
#                                                                      'activation_393[0][0]',
#                                                                      'activation_394[0][0]']
#
#  conv2d_398 (Conv2D)         (None, 7, 7, 64)             18432     ['mixed1[0][0]']
#
#  batch_normalization_398 (B  (None, 7, 7, 64)             192       ['conv2d_398[0][0]']
#  atchNormalization)
#
#  activation_398 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_398[0][0
#  )                                                                  ]']
#
#  conv2d_396 (Conv2D)         (None, 7, 7, 48)             13824     ['mixed1[0][0]']
#
#  conv2d_399 (Conv2D)         (None, 7, 7, 96)             55296     ['activation_398[0][0]']
#
#  batch_normalization_396 (B  (None, 7, 7, 48)             144       ['conv2d_396[0][0]']
#  atchNormalization)
#
#  batch_normalization_399 (B  (None, 7, 7, 96)             288       ['conv2d_399[0][0]']
#  atchNormalization)
#
#  activation_396 (Activation  (None, 7, 7, 48)             0         ['batch_normalization_396[0][0
#  )                                                                  ]']
#
#  activation_399 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_399[0][0
#  )                                                                  ]']
#
#  average_pooling2d_38 (Aver  (None, 7, 7, 288)            0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_395 (Conv2D)         (None, 7, 7, 64)             18432     ['mixed1[0][0]']
#
#  conv2d_397 (Conv2D)         (None, 7, 7, 64)             76800     ['activation_396[0][0]']
#
#  conv2d_400 (Conv2D)         (None, 7, 7, 96)             82944     ['activation_399[0][0]']
#
#  conv2d_401 (Conv2D)         (None, 7, 7, 64)             18432     ['average_pooling2d_38[0][0]']
#
#  batch_normalization_395 (B  (None, 7, 7, 64)             192       ['conv2d_395[0][0]']
#  atchNormalization)
#
#  batch_normalization_397 (B  (None, 7, 7, 64)             192       ['conv2d_397[0][0]']
#  atchNormalization)
#
#  batch_normalization_400 (B  (None, 7, 7, 96)             288       ['conv2d_400[0][0]']
#  atchNormalization)
#
#  batch_normalization_401 (B  (None, 7, 7, 64)             192       ['conv2d_401[0][0]']
#  atchNormalization)
#
#  activation_395 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_395[0][0
#  )                                                                  ]']
#
#  activation_397 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_397[0][0
#  )                                                                  ]']
#
#  activation_400 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_400[0][0
#  )                                                                  ]']
#
#  activation_401 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_401[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 7, 7, 288)            0         ['activation_395[0][0]',
#                                                                      'activation_397[0][0]',
#                                                                      'activation_400[0][0]',
#                                                                      'activation_401[0][0]']
#
#  conv2d_403 (Conv2D)         (None, 7, 7, 64)             18432     ['mixed2[0][0]']
#
#  batch_normalization_403 (B  (None, 7, 7, 64)             192       ['conv2d_403[0][0]']
#  atchNormalization)
#
#  activation_403 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_403[0][0
#  )                                                                  ]']
#
#  conv2d_404 (Conv2D)         (None, 7, 7, 96)             55296     ['activation_403[0][0]']
#
#  batch_normalization_404 (B  (None, 7, 7, 96)             288       ['conv2d_404[0][0]']
#  atchNormalization)
#
#  activation_404 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_404[0][0
#  )                                                                  ]']
#
#  conv2d_402 (Conv2D)         (None, 3, 3, 384)            995328    ['mixed2[0][0]']
#
#  conv2d_405 (Conv2D)         (None, 3, 3, 96)             82944     ['activation_404[0][0]']
#
#  batch_normalization_402 (B  (None, 3, 3, 384)            1152      ['conv2d_402[0][0]']
#  atchNormalization)
#
#  batch_normalization_405 (B  (None, 3, 3, 96)             288       ['conv2d_405[0][0]']
#  atchNormalization)
#
#  activation_402 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_402[0][0
#  )                                                                  ]']
#
#  activation_405 (Activation  (None, 3, 3, 96)             0         ['batch_normalization_405[0][0
#  )                                                                  ]']
#
#  max_pooling2d_18 (MaxPooli  (None, 3, 3, 288)            0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 3, 3, 768)            0         ['activation_402[0][0]',
#                                                                      'activation_405[0][0]',
#                                                                      'max_pooling2d_18[0][0]']
#
#  conv2d_410 (Conv2D)         (None, 3, 3, 128)            98304     ['mixed3[0][0]']
#
#  batch_normalization_410 (B  (None, 3, 3, 128)            384       ['conv2d_410[0][0]']
#  atchNormalization)
#
#  activation_410 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_410[0][0
#  )                                                                  ]']
#
#  conv2d_411 (Conv2D)         (None, 3, 3, 128)            114688    ['activation_410[0][0]']
#
#  batch_normalization_411 (B  (None, 3, 3, 128)            384       ['conv2d_411[0][0]']
#  atchNormalization)
#
#  activation_411 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_411[0][0
#  )                                                                  ]']
#
#  conv2d_407 (Conv2D)         (None, 3, 3, 128)            98304     ['mixed3[0][0]']
#
#  conv2d_412 (Conv2D)         (None, 3, 3, 128)            114688    ['activation_411[0][0]']
#
#  batch_normalization_407 (B  (None, 3, 3, 128)            384       ['conv2d_407[0][0]']
#  atchNormalization)
#
#  batch_normalization_412 (B  (None, 3, 3, 128)            384       ['conv2d_412[0][0]']
#  atchNormalization)
#
#  activation_407 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_407[0][0
#  )                                                                  ]']
#
#  activation_412 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_412[0][0
#  )                                                                  ]']
#
#  conv2d_408 (Conv2D)         (None, 3, 3, 128)            114688    ['activation_407[0][0]']
#
#  conv2d_413 (Conv2D)         (None, 3, 3, 128)            114688    ['activation_412[0][0]']
#
#  batch_normalization_408 (B  (None, 3, 3, 128)            384       ['conv2d_408[0][0]']
#  atchNormalization)
#
#  batch_normalization_413 (B  (None, 3, 3, 128)            384       ['conv2d_413[0][0]']
#  atchNormalization)
#
#  activation_408 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_408[0][0
#  )                                                                  ]']
#
#  activation_413 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_413[0][0
#  )                                                                  ]']
#
#  average_pooling2d_39 (Aver  (None, 3, 3, 768)            0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_406 (Conv2D)         (None, 3, 3, 192)            147456    ['mixed3[0][0]']
#
#  conv2d_409 (Conv2D)         (None, 3, 3, 192)            172032    ['activation_408[0][0]']
#
#  conv2d_414 (Conv2D)         (None, 3, 3, 192)            172032    ['activation_413[0][0]']
#
#  conv2d_415 (Conv2D)         (None, 3, 3, 192)            147456    ['average_pooling2d_39[0][0]']
#
#  batch_normalization_406 (B  (None, 3, 3, 192)            576       ['conv2d_406[0][0]']
#  atchNormalization)
#
#  batch_normalization_409 (B  (None, 3, 3, 192)            576       ['conv2d_409[0][0]']
#  atchNormalization)
#
#  batch_normalization_414 (B  (None, 3, 3, 192)            576       ['conv2d_414[0][0]']
#  atchNormalization)
#
#  batch_normalization_415 (B  (None, 3, 3, 192)            576       ['conv2d_415[0][0]']
#  atchNormalization)
#
#  activation_406 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_406[0][0
#  )                                                                  ]']
#
#  activation_409 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_409[0][0
#  )                                                                  ]']
#
#  activation_414 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_414[0][0
#  )                                                                  ]']
#
#  activation_415 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_415[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 3, 3, 768)            0         ['activation_406[0][0]',
#                                                                      'activation_409[0][0]',
#                                                                      'activation_414[0][0]',
#                                                                      'activation_415[0][0]']
#
#  conv2d_420 (Conv2D)         (None, 3, 3, 160)            122880    ['mixed4[0][0]']
#
#  batch_normalization_420 (B  (None, 3, 3, 160)            480       ['conv2d_420[0][0]']
#  atchNormalization)
#
#  activation_420 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_420[0][0
#  )                                                                  ]']
#
#  conv2d_421 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_420[0][0]']
#
#  batch_normalization_421 (B  (None, 3, 3, 160)            480       ['conv2d_421[0][0]']
#  atchNormalization)
#
#  activation_421 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_421[0][0
#  )                                                                  ]']
#
#  conv2d_417 (Conv2D)         (None, 3, 3, 160)            122880    ['mixed4[0][0]']
#
#  conv2d_422 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_421[0][0]']
#
#  batch_normalization_417 (B  (None, 3, 3, 160)            480       ['conv2d_417[0][0]']
#  atchNormalization)
#
#  batch_normalization_422 (B  (None, 3, 3, 160)            480       ['conv2d_422[0][0]']
#  atchNormalization)
#
#  activation_417 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_417[0][0
#  )                                                                  ]']
#
#  activation_422 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_422[0][0
#  )                                                                  ]']
#
#  conv2d_418 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_417[0][0]']
#
#  conv2d_423 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_422[0][0]']
#
#  batch_normalization_418 (B  (None, 3, 3, 160)            480       ['conv2d_418[0][0]']
#  atchNormalization)
#
#  batch_normalization_423 (B  (None, 3, 3, 160)            480       ['conv2d_423[0][0]']
#  atchNormalization)
#
#  activation_418 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_418[0][0
#  )                                                                  ]']
#
#  activation_423 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_423[0][0
#  )                                                                  ]']
#
#  average_pooling2d_40 (Aver  (None, 3, 3, 768)            0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_416 (Conv2D)         (None, 3, 3, 192)            147456    ['mixed4[0][0]']
#
#  conv2d_419 (Conv2D)         (None, 3, 3, 192)            215040    ['activation_418[0][0]']
#
#  conv2d_424 (Conv2D)         (None, 3, 3, 192)            215040    ['activation_423[0][0]']
#
#  conv2d_425 (Conv2D)         (None, 3, 3, 192)            147456    ['average_pooling2d_40[0][0]']
#
#  batch_normalization_416 (B  (None, 3, 3, 192)            576       ['conv2d_416[0][0]']
#  atchNormalization)
#
#  batch_normalization_419 (B  (None, 3, 3, 192)            576       ['conv2d_419[0][0]']
#  atchNormalization)
#
#  batch_normalization_424 (B  (None, 3, 3, 192)            576       ['conv2d_424[0][0]']
#  atchNormalization)
#
#  batch_normalization_425 (B  (None, 3, 3, 192)            576       ['conv2d_425[0][0]']
#  atchNormalization)
#
#  activation_416 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_416[0][0
#  )                                                                  ]']
#
#  activation_419 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_419[0][0
#  )                                                                  ]']
#
#  activation_424 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_424[0][0
#  )                                                                  ]']
#
#  activation_425 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_425[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 3, 3, 768)            0         ['activation_416[0][0]',
#                                                                      'activation_419[0][0]',
#                                                                      'activation_424[0][0]',
#                                                                      'activation_425[0][0]']
#
#  conv2d_430 (Conv2D)         (None, 3, 3, 160)            122880    ['mixed5[0][0]']
#
#  batch_normalization_430 (B  (None, 3, 3, 160)            480       ['conv2d_430[0][0]']
#  atchNormalization)
#
#  activation_430 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_430[0][0
#  )                                                                  ]']
#
#  conv2d_431 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_430[0][0]']
#
#  batch_normalization_431 (B  (None, 3, 3, 160)            480       ['conv2d_431[0][0]']
#  atchNormalization)
#
#  activation_431 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_431[0][0
#  )                                                                  ]']
#
#  conv2d_427 (Conv2D)         (None, 3, 3, 160)            122880    ['mixed5[0][0]']
#
#  conv2d_432 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_431[0][0]']
#
#  batch_normalization_427 (B  (None, 3, 3, 160)            480       ['conv2d_427[0][0]']
#  atchNormalization)
#
#  batch_normalization_432 (B  (None, 3, 3, 160)            480       ['conv2d_432[0][0]']
#  atchNormalization)
#
# ...
#  )                                                                  ]']
#
#  conv2d_454 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_453[0][0]']
#
#  conv2d_455 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_453[0][0]']
#
#  conv2d_458 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_457[0][0]']
#
#  conv2d_459 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_457[0][0]']
#
#  average_pooling2d_43 (Aver  (None, 1, 1, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_452 (Conv2D)         (None, 1, 1, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_454 (B  (None, 1, 1, 384)            1152      ['conv2d_454[0][0]']
#  atchNormalization)
#
#  batch_normalization_455 (B  (None, 1, 1, 384)            1152      ['conv2d_455[0][0]']
#  atchNormalization)
#
#  batch_normalization_458 (B  (None, 1, 1, 384)            1152      ['conv2d_458[0][0]']
#  atchNormalization)
#
#  batch_normalization_459 (B  (None, 1, 1, 384)            1152      ['conv2d_459[0][0]']
#  atchNormalization)
#
#  conv2d_460 (Conv2D)         (None, 1, 1, 192)            245760    ['average_pooling2d_43[0][0]']
#
#  batch_normalization_452 (B  (None, 1, 1, 320)            960       ['conv2d_452[0][0]']
#  atchNormalization)
#
#  activation_454 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_454[0][0
#  )                                                                  ]']
#
#  activation_455 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_455[0][0
#  )                                                                  ]']
#
#  activation_458 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_458[0][0
#  )                                                                  ]']
#
#  activation_459 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_459[0][0
#  )                                                                  ]']
#
#  batch_normalization_460 (B  (None, 1, 1, 192)            576       ['conv2d_460[0][0]']
#  atchNormalization)
#
#  activation_452 (Activation  (None, 1, 1, 320)            0         ['batch_normalization_452[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 1, 1, 768)            0         ['activation_454[0][0]',
#                                                                      'activation_455[0][0]']
#
#  concatenate_8 (Concatenate  (None, 1, 1, 768)            0         ['activation_458[0][0]',
#  )                                                                   'activation_459[0][0]']
#
#  activation_460 (Activation  (None, 1, 1, 192)            0         ['batch_normalization_460[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 1, 1, 2048)           0         ['activation_452[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_8[0][0]',
#                                                                      'activation_460[0][0]']
#
#  conv2d_465 (Conv2D)         (None, 1, 1, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_465 (B  (None, 1, 1, 448)            1344      ['conv2d_465[0][0]']
#  atchNormalization)
#
#  activation_465 (Activation  (None, 1, 1, 448)            0         ['batch_normalization_465[0][0
#  )                                                                  ]']
#
#  conv2d_462 (Conv2D)         (None, 1, 1, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_466 (Conv2D)         (None, 1, 1, 384)            1548288   ['activation_465[0][0]']
#
#  batch_normalization_462 (B  (None, 1, 1, 384)            1152      ['conv2d_462[0][0]']
#  atchNormalization)
#
#  batch_normalization_466 (B  (None, 1, 1, 384)            1152      ['conv2d_466[0][0]']
#  atchNormalization)
#
#  activation_462 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_462[0][0
#  )                                                                  ]']
#
#  activation_466 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_466[0][0
#  )                                                                  ]']
#
#  conv2d_463 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_462[0][0]']
#
#  conv2d_464 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_462[0][0]']
#
#  conv2d_467 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_466[0][0]']
#
#  conv2d_468 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_466[0][0]']
#
#  average_pooling2d_44 (Aver  (None, 1, 1, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_461 (Conv2D)         (None, 1, 1, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_463 (B  (None, 1, 1, 384)            1152      ['conv2d_463[0][0]']
#  atchNormalization)
#
#  batch_normalization_464 (B  (None, 1, 1, 384)            1152      ['conv2d_464[0][0]']
#  atchNormalization)
#
#  batch_normalization_467 (B  (None, 1, 1, 384)            1152      ['conv2d_467[0][0]']
#  atchNormalization)
#
#  batch_normalization_468 (B  (None, 1, 1, 384)            1152      ['conv2d_468[0][0]']
#  atchNormalization)
#
#  conv2d_469 (Conv2D)         (None, 1, 1, 192)            393216    ['average_pooling2d_44[0][0]']
#
#  batch_normalization_461 (B  (None, 1, 1, 320)            960       ['conv2d_461[0][0]']
#  atchNormalization)
#
#  activation_463 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_463[0][0
#  )                                                                  ]']
#
#  activation_464 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_464[0][0
#  )                                                                  ]']
#
#  activation_467 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_467[0][0
#  )                                                                  ]']
#
#  activation_468 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_468[0][0
#  )                                                                  ]']
#
#  batch_normalization_469 (B  (None, 1, 1, 192)            576       ['conv2d_469[0][0]']
#  atchNormalization)
#
#  activation_461 (Activation  (None, 1, 1, 320)            0         ['batch_normalization_461[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 1, 1, 768)            0         ['activation_463[0][0]',
#                                                                      'activation_464[0][0]']
#
#  concatenate_9 (Concatenate  (None, 1, 1, 768)            0         ['activation_467[0][0]',
#  )                                                                   'activation_468[0][0]']
#
#  activation_469 (Activation  (None, 1, 1, 192)            0         ['batch_normalization_469[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 1, 1, 2048)           0         ['activation_461[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_9[0][0]',
#                                                                      'activation_469[0][0]']
#
#  flatten_4 (Flatten)         (None, 2048)                 0         ['mixed10[0][0]']
#
#  dense_8 (Dense)             (None, 2048)                 4196352   ['flatten_4[0][0]']
#
#  dropout_4 (Dropout)         (None, 2048)                 0         ['dense_8[0][0]']
#
#  dense_9 (Dense)             (None, 6)                    12294     ['dropout_4[0][0]']
#
# ==================================================================================================
# Total params: 26011430 (99.23 MB)
# Trainable params: 4208646 (16.05 MB)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________

# %%
IMG_WIDTH = IMG_HEIGHT = 75
# Cargamos el modelo pre-entrenado
base_model = InceptionV3(include_top=False, weights='imagenet', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3))

# Congelamos sus capas
for layer in base_model.layers:
    layer.trainable = False


# Capa de flatenizado de la salida del modelo base
def prepare_model(base_model = base_model): # Lo creamos así para poder reinicializarlo en cada reentrenamiento en ejercicios posteriores
    x = keras.layers.Flatten()(base_model.output)
    
    # Tantas unidades como el flatten de la salida de Inception -> 5625 features
    x = keras.layers.Dense(2048, activation='relu')(x)
    x = keras.layers.Dropout(rate = 0.25)(x)

    # Capa final de salida con 6 neuronas (una por clase) y activación softmax
    x = keras.layers.Dense(6, activation='softmax')(x)
    
    model = keras.Model(base_model.input, x)
    model.compile(optimizer = "adam", loss = 'sparse_categorical_crossentropy', metrics = ['acc']) # sparse -> y es un array de escalares pero hay varias categorias, y un array de vectores
    return model
# Observamos la arquitectura del modelo
model= prepare_model()
type(model.summary())
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 75, 75, 3)]          0         []
#
#  conv2d_564 (Conv2D)         (None, 37, 37, 32)           864       ['input_7[0][0]']
#
#  batch_normalization_564 (B  (None, 37, 37, 32)           96        ['conv2d_564[0][0]']
#  atchNormalization)
#
#  activation_564 (Activation  (None, 37, 37, 32)           0         ['batch_normalization_564[0][0
#  )                                                                  ]']
#
#  conv2d_565 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_564[0][0]']
#
#  batch_normalization_565 (B  (None, 35, 35, 32)           96        ['conv2d_565[0][0]']
#  atchNormalization)
#
#  activation_565 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_565[0][0
#  )                                                                  ]']
#
#  conv2d_566 (Conv2D)         (None, 35, 35, 64)           18432     ['activation_565[0][0]']
#
#  batch_normalization_566 (B  (None, 35, 35, 64)           192       ['conv2d_566[0][0]']
#  atchNormalization)
#
#  activation_566 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_566[0][0
#  )                                                                  ]']
#
#  max_pooling2d_24 (MaxPooli  (None, 17, 17, 64)           0         ['activation_566[0][0]']
#  ng2D)
#
#  conv2d_567 (Conv2D)         (None, 17, 17, 80)           5120      ['max_pooling2d_24[0][0]']
#
#  batch_normalization_567 (B  (None, 17, 17, 80)           240       ['conv2d_567[0][0]']
#  atchNormalization)
#
#  activation_567 (Activation  (None, 17, 17, 80)           0         ['batch_normalization_567[0][0
#  )                                                                  ]']
#
#  conv2d_568 (Conv2D)         (None, 15, 15, 192)          138240    ['activation_567[0][0]']
#
#  batch_normalization_568 (B  (None, 15, 15, 192)          576       ['conv2d_568[0][0]']
#  atchNormalization)
#
#  activation_568 (Activation  (None, 15, 15, 192)          0         ['batch_normalization_568[0][0
#  )                                                                  ]']
#
#  max_pooling2d_25 (MaxPooli  (None, 7, 7, 192)            0         ['activation_568[0][0]']
#  ng2D)
#
#  conv2d_572 (Conv2D)         (None, 7, 7, 64)             12288     ['max_pooling2d_25[0][0]']
#
#  batch_normalization_572 (B  (None, 7, 7, 64)             192       ['conv2d_572[0][0]']
#  atchNormalization)
#
#  activation_572 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_572[0][0
#  )                                                                  ]']
#
#  conv2d_570 (Conv2D)         (None, 7, 7, 48)             9216      ['max_pooling2d_25[0][0]']
#
#  conv2d_573 (Conv2D)         (None, 7, 7, 96)             55296     ['activation_572[0][0]']
#
#  batch_normalization_570 (B  (None, 7, 7, 48)             144       ['conv2d_570[0][0]']
#  atchNormalization)
#
#  batch_normalization_573 (B  (None, 7, 7, 96)             288       ['conv2d_573[0][0]']
#  atchNormalization)
#
#  activation_570 (Activation  (None, 7, 7, 48)             0         ['batch_normalization_570[0][0
#  )                                                                  ]']
#
#  activation_573 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_573[0][0
#  )                                                                  ]']
#
#  average_pooling2d_54 (Aver  (None, 7, 7, 192)            0         ['max_pooling2d_25[0][0]']
#  agePooling2D)
#
#  conv2d_569 (Conv2D)         (None, 7, 7, 64)             12288     ['max_pooling2d_25[0][0]']
#
#  conv2d_571 (Conv2D)         (None, 7, 7, 64)             76800     ['activation_570[0][0]']
#
#  conv2d_574 (Conv2D)         (None, 7, 7, 96)             82944     ['activation_573[0][0]']
#
#  conv2d_575 (Conv2D)         (None, 7, 7, 32)             6144      ['average_pooling2d_54[0][0]']
#
#  batch_normalization_569 (B  (None, 7, 7, 64)             192       ['conv2d_569[0][0]']
#  atchNormalization)
#
#  batch_normalization_571 (B  (None, 7, 7, 64)             192       ['conv2d_571[0][0]']
#  atchNormalization)
#
#  batch_normalization_574 (B  (None, 7, 7, 96)             288       ['conv2d_574[0][0]']
#  atchNormalization)
#
#  batch_normalization_575 (B  (None, 7, 7, 32)             96        ['conv2d_575[0][0]']
#  atchNormalization)
#
#  activation_569 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_569[0][0
#  )                                                                  ]']
#
#  activation_571 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_571[0][0
#  )                                                                  ]']
#
#  activation_574 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_574[0][0
#  )                                                                  ]']
#
#  activation_575 (Activation  (None, 7, 7, 32)             0         ['batch_normalization_575[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 7, 7, 256)            0         ['activation_569[0][0]',
#                                                                      'activation_571[0][0]',
#                                                                      'activation_574[0][0]',
#                                                                      'activation_575[0][0]']
#
#  conv2d_579 (Conv2D)         (None, 7, 7, 64)             16384     ['mixed0[0][0]']
#
#  batch_normalization_579 (B  (None, 7, 7, 64)             192       ['conv2d_579[0][0]']
#  atchNormalization)
#
#  activation_579 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_579[0][0
#  )                                                                  ]']
#
#  conv2d_577 (Conv2D)         (None, 7, 7, 48)             12288     ['mixed0[0][0]']
#
#  conv2d_580 (Conv2D)         (None, 7, 7, 96)             55296     ['activation_579[0][0]']
#
#  batch_normalization_577 (B  (None, 7, 7, 48)             144       ['conv2d_577[0][0]']
#  atchNormalization)
#
#  batch_normalization_580 (B  (None, 7, 7, 96)             288       ['conv2d_580[0][0]']
#  atchNormalization)
#
#  activation_577 (Activation  (None, 7, 7, 48)             0         ['batch_normalization_577[0][0
#  )                                                                  ]']
#
#  activation_580 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_580[0][0
#  )                                                                  ]']
#
#  average_pooling2d_55 (Aver  (None, 7, 7, 256)            0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_576 (Conv2D)         (None, 7, 7, 64)             16384     ['mixed0[0][0]']
#
#  conv2d_578 (Conv2D)         (None, 7, 7, 64)             76800     ['activation_577[0][0]']
#
#  conv2d_581 (Conv2D)         (None, 7, 7, 96)             82944     ['activation_580[0][0]']
#
#  conv2d_582 (Conv2D)         (None, 7, 7, 64)             16384     ['average_pooling2d_55[0][0]']
#
#  batch_normalization_576 (B  (None, 7, 7, 64)             192       ['conv2d_576[0][0]']
#  atchNormalization)
#
#  batch_normalization_578 (B  (None, 7, 7, 64)             192       ['conv2d_578[0][0]']
#  atchNormalization)
#
#  batch_normalization_581 (B  (None, 7, 7, 96)             288       ['conv2d_581[0][0]']
#  atchNormalization)
#
#  batch_normalization_582 (B  (None, 7, 7, 64)             192       ['conv2d_582[0][0]']
#  atchNormalization)
#
#  activation_576 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_576[0][0
#  )                                                                  ]']
#
#  activation_578 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_578[0][0
#  )                                                                  ]']
#
#  activation_581 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_581[0][0
#  )                                                                  ]']
#
#  activation_582 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_582[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 7, 7, 288)            0         ['activation_576[0][0]',
#                                                                      'activation_578[0][0]',
#                                                                      'activation_581[0][0]',
#                                                                      'activation_582[0][0]']
#
#  conv2d_586 (Conv2D)         (None, 7, 7, 64)             18432     ['mixed1[0][0]']
#
#  batch_normalization_586 (B  (None, 7, 7, 64)             192       ['conv2d_586[0][0]']
#  atchNormalization)
#
#  activation_586 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_586[0][0
#  )                                                                  ]']
#
#  conv2d_584 (Conv2D)         (None, 7, 7, 48)             13824     ['mixed1[0][0]']
#
#  conv2d_587 (Conv2D)         (None, 7, 7, 96)             55296     ['activation_586[0][0]']
#
#  batch_normalization_584 (B  (None, 7, 7, 48)             144       ['conv2d_584[0][0]']
#  atchNormalization)
#
#  batch_normalization_587 (B  (None, 7, 7, 96)             288       ['conv2d_587[0][0]']
#  atchNormalization)
#
#  activation_584 (Activation  (None, 7, 7, 48)             0         ['batch_normalization_584[0][0
#  )                                                                  ]']
#
#  activation_587 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_587[0][0
#  )                                                                  ]']
#
#  average_pooling2d_56 (Aver  (None, 7, 7, 288)            0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_583 (Conv2D)         (None, 7, 7, 64)             18432     ['mixed1[0][0]']
#
#  conv2d_585 (Conv2D)         (None, 7, 7, 64)             76800     ['activation_584[0][0]']
#
#  conv2d_588 (Conv2D)         (None, 7, 7, 96)             82944     ['activation_587[0][0]']
#
#  conv2d_589 (Conv2D)         (None, 7, 7, 64)             18432     ['average_pooling2d_56[0][0]']
#
#  batch_normalization_583 (B  (None, 7, 7, 64)             192       ['conv2d_583[0][0]']
#  atchNormalization)
#
#  batch_normalization_585 (B  (None, 7, 7, 64)             192       ['conv2d_585[0][0]']
#  atchNormalization)
#
#  batch_normalization_588 (B  (None, 7, 7, 96)             288       ['conv2d_588[0][0]']
#  atchNormalization)
#
#  batch_normalization_589 (B  (None, 7, 7, 64)             192       ['conv2d_589[0][0]']
#  atchNormalization)
#
#  activation_583 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_583[0][0
#  )                                                                  ]']
#
#  activation_585 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_585[0][0
#  )                                                                  ]']
#
#  activation_588 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_588[0][0
#  )                                                                  ]']
#
#  activation_589 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_589[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 7, 7, 288)            0         ['activation_583[0][0]',
#                                                                      'activation_585[0][0]',
#                                                                      'activation_588[0][0]',
#                                                                      'activation_589[0][0]']
#
#  conv2d_591 (Conv2D)         (None, 7, 7, 64)             18432     ['mixed2[0][0]']
#
#  batch_normalization_591 (B  (None, 7, 7, 64)             192       ['conv2d_591[0][0]']
#  atchNormalization)
#
#  activation_591 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_591[0][0
#  )                                                                  ]']
#
#  conv2d_592 (Conv2D)         (None, 7, 7, 96)             55296     ['activation_591[0][0]']
#
#  batch_normalization_592 (B  (None, 7, 7, 96)             288       ['conv2d_592[0][0]']
#  atchNormalization)
#
#  activation_592 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_592[0][0
#  )                                                                  ]']
#
#  conv2d_590 (Conv2D)         (None, 3, 3, 384)            995328    ['mixed2[0][0]']
#
#  conv2d_593 (Conv2D)         (None, 3, 3, 96)             82944     ['activation_592[0][0]']
#
#  batch_normalization_590 (B  (None, 3, 3, 384)            1152      ['conv2d_590[0][0]']
#  atchNormalization)
#
#  batch_normalization_593 (B  (None, 3, 3, 96)             288       ['conv2d_593[0][0]']
#  atchNormalization)
#
#  activation_590 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_590[0][0
#  )                                                                  ]']
#
#  activation_593 (Activation  (None, 3, 3, 96)             0         ['batch_normalization_593[0][0
#  )                                                                  ]']
#
#  max_pooling2d_26 (MaxPooli  (None, 3, 3, 288)            0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 3, 3, 768)            0         ['activation_590[0][0]',
#                                                                      'activation_593[0][0]',
#                                                                      'max_pooling2d_26[0][0]']
#
#  conv2d_598 (Conv2D)         (None, 3, 3, 128)            98304     ['mixed3[0][0]']
#
#  batch_normalization_598 (B  (None, 3, 3, 128)            384       ['conv2d_598[0][0]']
#  atchNormalization)
#
#  activation_598 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_598[0][0
#  )                                                                  ]']
#
#  conv2d_599 (Conv2D)         (None, 3, 3, 128)            114688    ['activation_598[0][0]']
#
#  batch_normalization_599 (B  (None, 3, 3, 128)            384       ['conv2d_599[0][0]']
#  atchNormalization)
#
#  activation_599 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_599[0][0
#  )                                                                  ]']
#
#  conv2d_595 (Conv2D)         (None, 3, 3, 128)            98304     ['mixed3[0][0]']
#
#  conv2d_600 (Conv2D)         (None, 3, 3, 128)            114688    ['activation_599[0][0]']
#
#  batch_normalization_595 (B  (None, 3, 3, 128)            384       ['conv2d_595[0][0]']
#  atchNormalization)
#
#  batch_normalization_600 (B  (None, 3, 3, 128)            384       ['conv2d_600[0][0]']
#  atchNormalization)
#
#  activation_595 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_595[0][0
#  )                                                                  ]']
#
#  activation_600 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_600[0][0
#  )                                                                  ]']
#
#  conv2d_596 (Conv2D)         (None, 3, 3, 128)            114688    ['activation_595[0][0]']
#
#  conv2d_601 (Conv2D)         (None, 3, 3, 128)            114688    ['activation_600[0][0]']
#
#  batch_normalization_596 (B  (None, 3, 3, 128)            384       ['conv2d_596[0][0]']
#  atchNormalization)
#
#  batch_normalization_601 (B  (None, 3, 3, 128)            384       ['conv2d_601[0][0]']
#  atchNormalization)
#
#  activation_596 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_596[0][0
#  )                                                                  ]']
#
#  activation_601 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_601[0][0
#  )                                                                  ]']
#
#  average_pooling2d_57 (Aver  (None, 3, 3, 768)            0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_594 (Conv2D)         (None, 3, 3, 192)            147456    ['mixed3[0][0]']
#
#  conv2d_597 (Conv2D)         (None, 3, 3, 192)            172032    ['activation_596[0][0]']
#
#  conv2d_602 (Conv2D)         (None, 3, 3, 192)            172032    ['activation_601[0][0]']
#
#  conv2d_603 (Conv2D)         (None, 3, 3, 192)            147456    ['average_pooling2d_57[0][0]']
#
#  batch_normalization_594 (B  (None, 3, 3, 192)            576       ['conv2d_594[0][0]']
#  atchNormalization)
#
#  batch_normalization_597 (B  (None, 3, 3, 192)            576       ['conv2d_597[0][0]']
#  atchNormalization)
#
#  batch_normalization_602 (B  (None, 3, 3, 192)            576       ['conv2d_602[0][0]']
#  atchNormalization)
#
#  batch_normalization_603 (B  (None, 3, 3, 192)            576       ['conv2d_603[0][0]']
#  atchNormalization)
#
#  activation_594 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_594[0][0
#  )                                                                  ]']
#
#  activation_597 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_597[0][0
#  )                                                                  ]']
#
#  activation_602 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_602[0][0
#  )                                                                  ]']
#
#  activation_603 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_603[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 3, 3, 768)            0         ['activation_594[0][0]',
#                                                                      'activation_597[0][0]',
#                                                                      'activation_602[0][0]',
#                                                                      'activation_603[0][0]']
#
#  conv2d_608 (Conv2D)         (None, 3, 3, 160)            122880    ['mixed4[0][0]']
#
#  batch_normalization_608 (B  (None, 3, 3, 160)            480       ['conv2d_608[0][0]']
#  atchNormalization)
#
#  activation_608 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_608[0][0
#  )                                                                  ]']
#
#  conv2d_609 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_608[0][0]']
#
#  batch_normalization_609 (B  (None, 3, 3, 160)            480       ['conv2d_609[0][0]']
#  atchNormalization)
#
#  activation_609 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_609[0][0
#  )                                                                  ]']
#
#  conv2d_605 (Conv2D)         (None, 3, 3, 160)            122880    ['mixed4[0][0]']
#
#  conv2d_610 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_609[0][0]']
#
#  batch_normalization_605 (B  (None, 3, 3, 160)            480       ['conv2d_605[0][0]']
#  atchNormalization)
#
#  batch_normalization_610 (B  (None, 3, 3, 160)            480       ['conv2d_610[0][0]']
#  atchNormalization)
#
#  activation_605 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_605[0][0
#  )                                                                  ]']
#
#  activation_610 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_610[0][0
#  )                                                                  ]']
#
#  conv2d_606 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_605[0][0]']
#
#  conv2d_611 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_610[0][0]']
#
#  batch_normalization_606 (B  (None, 3, 3, 160)            480       ['conv2d_606[0][0]']
#  atchNormalization)
#
#  batch_normalization_611 (B  (None, 3, 3, 160)            480       ['conv2d_611[0][0]']
#  atchNormalization)
#
#  activation_606 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_606[0][0
#  )                                                                  ]']
#
#  activation_611 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_611[0][0
#  )                                                                  ]']
#
#  average_pooling2d_58 (Aver  (None, 3, 3, 768)            0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_604 (Conv2D)         (None, 3, 3, 192)            147456    ['mixed4[0][0]']
#
#  conv2d_607 (Conv2D)         (None, 3, 3, 192)            215040    ['activation_606[0][0]']
#
#  conv2d_612 (Conv2D)         (None, 3, 3, 192)            215040    ['activation_611[0][0]']
#
#  conv2d_613 (Conv2D)         (None, 3, 3, 192)            147456    ['average_pooling2d_58[0][0]']
#
#  batch_normalization_604 (B  (None, 3, 3, 192)            576       ['conv2d_604[0][0]']
#  atchNormalization)
#
#  batch_normalization_607 (B  (None, 3, 3, 192)            576       ['conv2d_607[0][0]']
#  atchNormalization)
#
#  batch_normalization_612 (B  (None, 3, 3, 192)            576       ['conv2d_612[0][0]']
#  atchNormalization)
#
#  batch_normalization_613 (B  (None, 3, 3, 192)            576       ['conv2d_613[0][0]']
#  atchNormalization)
#
#  activation_604 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_604[0][0
#  )                                                                  ]']
#
#  activation_607 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_607[0][0
#  )                                                                  ]']
#
#  activation_612 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_612[0][0
#  )                                                                  ]']
#
#  activation_613 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_613[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 3, 3, 768)            0         ['activation_604[0][0]',
#                                                                      'activation_607[0][0]',
#                                                                      'activation_612[0][0]',
#                                                                      'activation_613[0][0]']
#
#  conv2d_618 (Conv2D)         (None, 3, 3, 160)            122880    ['mixed5[0][0]']
#
#  batch_normalization_618 (B  (None, 3, 3, 160)            480       ['conv2d_618[0][0]']
#  atchNormalization)
#
#  activation_618 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_618[0][0
#  )                                                                  ]']
#
#  conv2d_619 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_618[0][0]']
#
#  batch_normalization_619 (B  (None, 3, 3, 160)            480       ['conv2d_619[0][0]']
#  atchNormalization)
#
#  activation_619 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_619[0][0
#  )                                                                  ]']
#
#  conv2d_615 (Conv2D)         (None, 3, 3, 160)            122880    ['mixed5[0][0]']
#
#  conv2d_620 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_619[0][0]']
#
#  batch_normalization_615 (B  (None, 3, 3, 160)            480       ['conv2d_615[0][0]']
#  atchNormalization)
#
#  batch_normalization_620 (B  (None, 3, 3, 160)            480       ['conv2d_620[0][0]']
#  atchNormalization)
#
# ...
#  )                                                                  ]']
#
#  conv2d_642 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_641[0][0]']
#
#  conv2d_643 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_641[0][0]']
#
#  conv2d_646 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_645[0][0]']
#
#  conv2d_647 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_645[0][0]']
#
#  average_pooling2d_61 (Aver  (None, 1, 1, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_640 (Conv2D)         (None, 1, 1, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_642 (B  (None, 1, 1, 384)            1152      ['conv2d_642[0][0]']
#  atchNormalization)
#
#  batch_normalization_643 (B  (None, 1, 1, 384)            1152      ['conv2d_643[0][0]']
#  atchNormalization)
#
#  batch_normalization_646 (B  (None, 1, 1, 384)            1152      ['conv2d_646[0][0]']
#  atchNormalization)
#
#  batch_normalization_647 (B  (None, 1, 1, 384)            1152      ['conv2d_647[0][0]']
#  atchNormalization)
#
#  conv2d_648 (Conv2D)         (None, 1, 1, 192)            245760    ['average_pooling2d_61[0][0]']
#
#  batch_normalization_640 (B  (None, 1, 1, 320)            960       ['conv2d_640[0][0]']
#  atchNormalization)
#
#  activation_642 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_642[0][0
#  )                                                                  ]']
#
#  activation_643 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_643[0][0
#  )                                                                  ]']
#
#  activation_646 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_646[0][0
#  )                                                                  ]']
#
#  activation_647 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_647[0][0
#  )                                                                  ]']
#
#  batch_normalization_648 (B  (None, 1, 1, 192)            576       ['conv2d_648[0][0]']
#  atchNormalization)
#
#  activation_640 (Activation  (None, 1, 1, 320)            0         ['batch_normalization_640[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 1, 1, 768)            0         ['activation_642[0][0]',
#                                                                      'activation_643[0][0]']
#
#  concatenate_12 (Concatenat  (None, 1, 1, 768)            0         ['activation_646[0][0]',
#  e)                                                                  'activation_647[0][0]']
#
#  activation_648 (Activation  (None, 1, 1, 192)            0         ['batch_normalization_648[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 1, 1, 2048)           0         ['activation_640[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_12[0][0]',
#                                                                      'activation_648[0][0]']
#
#  conv2d_653 (Conv2D)         (None, 1, 1, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_653 (B  (None, 1, 1, 448)            1344      ['conv2d_653[0][0]']
#  atchNormalization)
#
#  activation_653 (Activation  (None, 1, 1, 448)            0         ['batch_normalization_653[0][0
#  )                                                                  ]']
#
#  conv2d_650 (Conv2D)         (None, 1, 1, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_654 (Conv2D)         (None, 1, 1, 384)            1548288   ['activation_653[0][0]']
#
#  batch_normalization_650 (B  (None, 1, 1, 384)            1152      ['conv2d_650[0][0]']
#  atchNormalization)
#
#  batch_normalization_654 (B  (None, 1, 1, 384)            1152      ['conv2d_654[0][0]']
#  atchNormalization)
#
#  activation_650 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_650[0][0
#  )                                                                  ]']
#
#  activation_654 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_654[0][0
#  )                                                                  ]']
#
#  conv2d_651 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_650[0][0]']
#
#  conv2d_652 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_650[0][0]']
#
#  conv2d_655 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_654[0][0]']
#
#  conv2d_656 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_654[0][0]']
#
#  average_pooling2d_62 (Aver  (None, 1, 1, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_649 (Conv2D)         (None, 1, 1, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_651 (B  (None, 1, 1, 384)            1152      ['conv2d_651[0][0]']
#  atchNormalization)
#
#  batch_normalization_652 (B  (None, 1, 1, 384)            1152      ['conv2d_652[0][0]']
#  atchNormalization)
#
#  batch_normalization_655 (B  (None, 1, 1, 384)            1152      ['conv2d_655[0][0]']
#  atchNormalization)
#
#  batch_normalization_656 (B  (None, 1, 1, 384)            1152      ['conv2d_656[0][0]']
#  atchNormalization)
#
#  conv2d_657 (Conv2D)         (None, 1, 1, 192)            393216    ['average_pooling2d_62[0][0]']
#
#  batch_normalization_649 (B  (None, 1, 1, 320)            960       ['conv2d_649[0][0]']
#  atchNormalization)
#
#  activation_651 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_651[0][0
#  )                                                                  ]']
#
#  activation_652 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_652[0][0
#  )                                                                  ]']
#
#  activation_655 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_655[0][0
#  )                                                                  ]']
#
#  activation_656 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_656[0][0
#  )                                                                  ]']
#
#  batch_normalization_657 (B  (None, 1, 1, 192)            576       ['conv2d_657[0][0]']
#  atchNormalization)
#
#  activation_649 (Activation  (None, 1, 1, 320)            0         ['batch_normalization_649[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 1, 1, 768)            0         ['activation_651[0][0]',
#                                                                      'activation_652[0][0]']
#
#  concatenate_13 (Concatenat  (None, 1, 1, 768)            0         ['activation_655[0][0]',
#  e)                                                                  'activation_656[0][0]']
#
#  activation_657 (Activation  (None, 1, 1, 192)            0         ['batch_normalization_657[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 1, 1, 2048)           0         ['activation_649[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_13[0][0]',
#                                                                      'activation_657[0][0]']
#
#  flatten_6 (Flatten)         (None, 2048)                 0         ['mixed10[0][0]']
#
#  dense_12 (Dense)            (None, 2048)                 4196352   ['flatten_6[0][0]']
#
#  dropout_6 (Dropout)         (None, 2048)                 0         ['dense_12[0][0]']
#
#  dense_13 (Dense)            (None, 6)                    12294     ['dropout_6[0][0]']
#
# ==================================================================================================
# Total params: 26011430 (99.23 MB)
# Trainable params: 4208646 (16.05 MB)
# Non-trainable params: 21802784 (83.17 MB)
# __________________________________________________________________________________________________
# NoneType

# %% [markdown]
# *Ahora vamos a configurar el resto de hiperparámetros, el batch_size, el número de épocas y el EarlyStopping*

# %%
instancias_train = len(X_train)
for i in range(1,5):
    print(f"Batch_size: {32*i}, num_steps_per_epoch: {round(instancias_train/(32*i))}")
# Out:
# Batch_size: 32, num_steps_per_epoch: 439
# Batch_size: 64, num_steps_per_epoch: 219
# Batch_size: 96, num_steps_per_epoch: 146
# Batch_size: 128, num_steps_per_epoch: 110

# %% [markdown]
# *Podemos atrevernos hasta con batches de 128, para saber cuál usar vamos a hacer un entrenamiento de una época con cada uno y ver tiempos*

# %% [markdown]
# *Antes tendremos que convertir las etiquetas a números*

# %%
targets = pd.Series(y_train)

# %%
mapa = {tipo:indice for indice,tipo in enumerate(targets.unique())} # Rehusando la serie que creamos para ver la distribución del target
mapa
# Out:
# {'buildings': 0,
#  'forest': 1,
#  'glacier': 2,
#  'mountain': 3,
#  'sea': 4,
#  'street': 5}

# %%
y_train_num = np.array([mapa[y] for y in y_train])
y_test_num = np.array([mapa[y] for y in y_test])

# %%
from time import time
for batch_size in [32,64,96,128]:
    t_zero = time()
    model = prepare_model()
    history = model.fit(X_train, 
                        y_train_num,
                        batch_size = batch_size,
                        validation_split=0.2,
                        epochs=1,)
    tiempo = round(time() - t_zero, 3)
    print(f"batch_size: {batch_size}, num_steps: {len(X_train)/batch_size}, tiempo 1 epoca: {tiempo}, tiempo 20 épocas: {tiempo * 20}")
# Out:
# WARNING:tensorflow:From c:\Users\edici\Online_Env\Curso_Online_DATA\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\edici\Online_Env\Curso_Online_DATA\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 351/351 [==============================] - 108s 275ms/step - loss: 0.7020 - acc: 0.7456 - val_loss: 12.3348 - val_acc: 0.1165
# batch_size: 32, num_steps: 438.5625, tiempo 1 epoca: 117.863, tiempo 20 épocas: 2357.26
# 176/176 [==============================] - 68s 330ms/step - loss: 0.6915 - acc: 0.7489 - val_loss: 10.6260 - val_acc: 0.0737
# batch_size: 64, num_steps: 219.28125, tiempo 1 epoca: 73.297, tiempo 20 épocas: 1465.94
# 117/117 [==============================] - 60s 440ms/step - loss: 0.6906 - acc: 0.7476 - val_loss: 11.6801 - val_acc: 0.0919
# batch_size: 96, num_steps: 146.1875, tiempo 1 epoca: 64.527, tiempo 20 épocas: 1290.54
# 88/88 [==============================] - 43s 412ms/step - loss: 0.7318 - acc: 0.7330 - val_loss: 12.1956 - val_acc: 0.0759
# batch_size: 128, num_steps: 109.640625, tiempo 1 epoca: 45.05, tiempo 20 épocas: 901.0

# %% [markdown]
# *Vamos a por los 128 de batch size*

# %%
batch_size
# Out:
# 128

# %%
earlyS = keras.callbacks.EarlyStopping(patience= 10, restore_best_weights= True)

# %%
from sklearn.utils import shuffle
X_train_s,y_train_s = shuffle(X_train, y_train_num)

# %%
t_zero = time()
model = prepare_model()
history = model.fit(X_train_s, 
                    y_train_s,
                    batch_size = batch_size,
                    validation_split=0.2,
                    epochs=40,
                    callbacks = [earlyS])
tiempo = round(time() - t_zero, 3)
# Out:
# Epoch 1/40
# 88/88 [==============================] - 32s 318ms/step - loss: 0.8441 - acc: 0.6964 - val_loss: 0.6293 - val_acc: 0.7670
# Epoch 2/40
# 88/88 [==============================] - 25s 287ms/step - loss: 0.4941 - acc: 0.8193 - val_loss: 0.6004 - val_acc: 0.7809
# Epoch 3/40
# 88/88 [==============================] - 25s 284ms/step - loss: 0.3696 - acc: 0.8681 - val_loss: 0.5985 - val_acc: 0.7845
# Epoch 4/40
# 88/88 [==============================] - 24s 274ms/step - loss: 0.2652 - acc: 0.9097 - val_loss: 0.6454 - val_acc: 0.7809
# Epoch 5/40
# 88/88 [==============================] - 24s 272ms/step - loss: 0.1791 - acc: 0.9455 - val_loss: 0.6913 - val_acc: 0.7770
# Epoch 6/40
# 88/88 [==============================] - 24s 274ms/step - loss: 0.1099 - acc: 0.9734 - val_loss: 0.7311 - val_acc: 0.7748
# Epoch 7/40
# 88/88 [==============================] - 24s 273ms/step - loss: 0.0694 - acc: 0.9862 - val_loss: 0.7820 - val_acc: 0.7741
# Epoch 8/40
# 88/88 [==============================] - 25s 287ms/step - loss: 0.0478 - acc: 0.9928 - val_loss: 0.7784 - val_acc: 0.7809
# Epoch 9/40
# 88/88 [==============================] - 24s 274ms/step - loss: 0.0357 - acc: 0.9951 - val_loss: 0.8104 - val_acc: 0.7845
# Epoch 10/40
# 88/88 [==============================] - 24s 276ms/step - loss: 0.0261 - acc: 0.9964 - val_loss: 0.8658 - val_acc: 0.7770
# Epoch 11/40
# 88/88 [==============================] - 24s 275ms/step - loss: 0.0222 - acc: 0.9974 - val_loss: 0.9071 - val_acc: 0.7820
# Epoch 12/40
# 88/88 [==============================] - 24s 274ms/step - loss: 0.0193 - acc: 0.9981 - val_loss: 0.9044 - val_acc: 0.7820
# Epoch 13/40
# 88/88 [==============================] - 25s 280ms/step - loss: 0.0149 - acc: 0.9985 - val_loss: 0.9437 - val_acc: 0.7738

# %% [markdown]
# *Evaluamos*

# %%
model.evaluate(X_test,y_test_num)
# Out:
# 94/94 [==============================] - 6s 65ms/step - loss: 0.6151 - acc: 0.7820
# [0.6151329278945923, 0.7820000052452087]

# %% [markdown]
# *Un 78% que es un 2% mejor que la convolucional "sencilla", no es mucha ganancia para tanto armatoste. ¿Podríamos mejorar la cabeza decisora?*

# %% [markdown]
# *Completemos con el análisis del informe de clasificación y de la matriz de confusión*

# %%
y_pred = [ np.argmax(prediction) for prediction in model.predict(X_test)]
# Out:
# 94/94 [==============================] - 9s 71ms/step

# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
inverse_map = {valor:clave for clave,valor in mapa.items()}
y_test_labels = [inverse_map[y] for y in y_test_num]
y_pred_labels = [inverse_map[y] for y in y_pred]
print(classification_report(y_test_labels, y_pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#    buildings       0.82      0.84      0.83       437
#       forest       0.91      0.93      0.92       474
#      glacier       0.73      0.65      0.69       553
#     mountain       0.67      0.70      0.68       525
#          sea       0.74      0.79      0.76       510
#       street       0.84      0.82      0.83       501
#
#     accuracy                           0.78      3000
#    macro avg       0.79      0.79      0.79      3000
# weighted avg       0.78      0.78      0.78      3000

# %%
ConfusionMatrixDisplay.from_predictions(y_test_labels, y_pred_labels, normalize="true")

# %% [markdown]
# *Confunde montañas con glaciares y viceversa (las clases peor paradas), aunque las montañas también las confunde con el mar. Es peor en las montañas que el clasificador del ejercicio pero mejor sensiblemente en los edificios y mejor en los glaciares (las dos clases "malas" del clasificador de los ejercicios). Al igual que el clasificador del ejercicio confunde calles con edificios.*

# %% [markdown]
# ### Fine-Tuning

# %% [markdown]
# *Mantenemos la Inception V3**

# %%
# Cargamos el modelo pre-entrenado
base_model = InceptionV3(include_top=False, weights=None, input_shape=(IMG_WIDTH, IMG_HEIGHT, 3))

# Congelamos sus capas
#for layer in base_model.layers:
#    layer.trainable = False


# Capa de flatenizado de la salida del modelo base
def prepare_model(base_model = base_model): # Lo creamos así para poder reinicializarlo en cada reentrenamiento en ejercicios posteriores
    x = keras.layers.Flatten()(base_model.output)
    
    # Tantas unidades como el flatten de la salida de Inception
    x = keras.layers.Dense(2048, activation='relu')(x)
    x = keras.layers.Dropout(rate = 0.25)(x)

    
    # Capa final de salida con 6 neuronas (una por clase) y activación softmax
    x = keras.layers.Dense(6, activation='softmax')(x)
    
    model = keras.Model(base_model.input, x)
    model.compile(optimizer = "adam", loss = 'sparse_categorical_crossentropy', metrics = ['acc'])
    return model
# Observamos la arquitectura del modelo
model= prepare_model()
model.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 75, 75, 3)]          0         []
#
#  conv2d_470 (Conv2D)         (None, 37, 37, 32)           864       ['input_7[0][0]']
#
#  batch_normalization_470 (B  (None, 37, 37, 32)           96        ['conv2d_470[0][0]']
#  atchNormalization)
#
#  activation_470 (Activation  (None, 37, 37, 32)           0         ['batch_normalization_470[0][0
#  )                                                                  ]']
#
#  conv2d_471 (Conv2D)         (None, 35, 35, 32)           9216      ['activation_470[0][0]']
#
#  batch_normalization_471 (B  (None, 35, 35, 32)           96        ['conv2d_471[0][0]']
#  atchNormalization)
#
#  activation_471 (Activation  (None, 35, 35, 32)           0         ['batch_normalization_471[0][0
#  )                                                                  ]']
#
#  conv2d_472 (Conv2D)         (None, 35, 35, 64)           18432     ['activation_471[0][0]']
#
#  batch_normalization_472 (B  (None, 35, 35, 64)           192       ['conv2d_472[0][0]']
#  atchNormalization)
#
#  activation_472 (Activation  (None, 35, 35, 64)           0         ['batch_normalization_472[0][0
#  )                                                                  ]']
#
#  max_pooling2d_20 (MaxPooli  (None, 17, 17, 64)           0         ['activation_472[0][0]']
#  ng2D)
#
#  conv2d_473 (Conv2D)         (None, 17, 17, 80)           5120      ['max_pooling2d_20[0][0]']
#
#  batch_normalization_473 (B  (None, 17, 17, 80)           240       ['conv2d_473[0][0]']
#  atchNormalization)
#
#  activation_473 (Activation  (None, 17, 17, 80)           0         ['batch_normalization_473[0][0
#  )                                                                  ]']
#
#  conv2d_474 (Conv2D)         (None, 15, 15, 192)          138240    ['activation_473[0][0]']
#
#  batch_normalization_474 (B  (None, 15, 15, 192)          576       ['conv2d_474[0][0]']
#  atchNormalization)
#
#  activation_474 (Activation  (None, 15, 15, 192)          0         ['batch_normalization_474[0][0
#  )                                                                  ]']
#
#  max_pooling2d_21 (MaxPooli  (None, 7, 7, 192)            0         ['activation_474[0][0]']
#  ng2D)
#
#  conv2d_478 (Conv2D)         (None, 7, 7, 64)             12288     ['max_pooling2d_21[0][0]']
#
#  batch_normalization_478 (B  (None, 7, 7, 64)             192       ['conv2d_478[0][0]']
#  atchNormalization)
#
#  activation_478 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_478[0][0
#  )                                                                  ]']
#
#  conv2d_476 (Conv2D)         (None, 7, 7, 48)             9216      ['max_pooling2d_21[0][0]']
#
#  conv2d_479 (Conv2D)         (None, 7, 7, 96)             55296     ['activation_478[0][0]']
#
#  batch_normalization_476 (B  (None, 7, 7, 48)             144       ['conv2d_476[0][0]']
#  atchNormalization)
#
#  batch_normalization_479 (B  (None, 7, 7, 96)             288       ['conv2d_479[0][0]']
#  atchNormalization)
#
#  activation_476 (Activation  (None, 7, 7, 48)             0         ['batch_normalization_476[0][0
#  )                                                                  ]']
#
#  activation_479 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_479[0][0
#  )                                                                  ]']
#
#  average_pooling2d_45 (Aver  (None, 7, 7, 192)            0         ['max_pooling2d_21[0][0]']
#  agePooling2D)
#
#  conv2d_475 (Conv2D)         (None, 7, 7, 64)             12288     ['max_pooling2d_21[0][0]']
#
#  conv2d_477 (Conv2D)         (None, 7, 7, 64)             76800     ['activation_476[0][0]']
#
#  conv2d_480 (Conv2D)         (None, 7, 7, 96)             82944     ['activation_479[0][0]']
#
#  conv2d_481 (Conv2D)         (None, 7, 7, 32)             6144      ['average_pooling2d_45[0][0]']
#
#  batch_normalization_475 (B  (None, 7, 7, 64)             192       ['conv2d_475[0][0]']
#  atchNormalization)
#
#  batch_normalization_477 (B  (None, 7, 7, 64)             192       ['conv2d_477[0][0]']
#  atchNormalization)
#
#  batch_normalization_480 (B  (None, 7, 7, 96)             288       ['conv2d_480[0][0]']
#  atchNormalization)
#
#  batch_normalization_481 (B  (None, 7, 7, 32)             96        ['conv2d_481[0][0]']
#  atchNormalization)
#
#  activation_475 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_475[0][0
#  )                                                                  ]']
#
#  activation_477 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_477[0][0
#  )                                                                  ]']
#
#  activation_480 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_480[0][0
#  )                                                                  ]']
#
#  activation_481 (Activation  (None, 7, 7, 32)             0         ['batch_normalization_481[0][0
#  )                                                                  ]']
#
#  mixed0 (Concatenate)        (None, 7, 7, 256)            0         ['activation_475[0][0]',
#                                                                      'activation_477[0][0]',
#                                                                      'activation_480[0][0]',
#                                                                      'activation_481[0][0]']
#
#  conv2d_485 (Conv2D)         (None, 7, 7, 64)             16384     ['mixed0[0][0]']
#
#  batch_normalization_485 (B  (None, 7, 7, 64)             192       ['conv2d_485[0][0]']
#  atchNormalization)
#
#  activation_485 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_485[0][0
#  )                                                                  ]']
#
#  conv2d_483 (Conv2D)         (None, 7, 7, 48)             12288     ['mixed0[0][0]']
#
#  conv2d_486 (Conv2D)         (None, 7, 7, 96)             55296     ['activation_485[0][0]']
#
#  batch_normalization_483 (B  (None, 7, 7, 48)             144       ['conv2d_483[0][0]']
#  atchNormalization)
#
#  batch_normalization_486 (B  (None, 7, 7, 96)             288       ['conv2d_486[0][0]']
#  atchNormalization)
#
#  activation_483 (Activation  (None, 7, 7, 48)             0         ['batch_normalization_483[0][0
#  )                                                                  ]']
#
#  activation_486 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_486[0][0
#  )                                                                  ]']
#
#  average_pooling2d_46 (Aver  (None, 7, 7, 256)            0         ['mixed0[0][0]']
#  agePooling2D)
#
#  conv2d_482 (Conv2D)         (None, 7, 7, 64)             16384     ['mixed0[0][0]']
#
#  conv2d_484 (Conv2D)         (None, 7, 7, 64)             76800     ['activation_483[0][0]']
#
#  conv2d_487 (Conv2D)         (None, 7, 7, 96)             82944     ['activation_486[0][0]']
#
#  conv2d_488 (Conv2D)         (None, 7, 7, 64)             16384     ['average_pooling2d_46[0][0]']
#
#  batch_normalization_482 (B  (None, 7, 7, 64)             192       ['conv2d_482[0][0]']
#  atchNormalization)
#
#  batch_normalization_484 (B  (None, 7, 7, 64)             192       ['conv2d_484[0][0]']
#  atchNormalization)
#
#  batch_normalization_487 (B  (None, 7, 7, 96)             288       ['conv2d_487[0][0]']
#  atchNormalization)
#
#  batch_normalization_488 (B  (None, 7, 7, 64)             192       ['conv2d_488[0][0]']
#  atchNormalization)
#
#  activation_482 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_482[0][0
#  )                                                                  ]']
#
#  activation_484 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_484[0][0
#  )                                                                  ]']
#
#  activation_487 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_487[0][0
#  )                                                                  ]']
#
#  activation_488 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_488[0][0
#  )                                                                  ]']
#
#  mixed1 (Concatenate)        (None, 7, 7, 288)            0         ['activation_482[0][0]',
#                                                                      'activation_484[0][0]',
#                                                                      'activation_487[0][0]',
#                                                                      'activation_488[0][0]']
#
#  conv2d_492 (Conv2D)         (None, 7, 7, 64)             18432     ['mixed1[0][0]']
#
#  batch_normalization_492 (B  (None, 7, 7, 64)             192       ['conv2d_492[0][0]']
#  atchNormalization)
#
#  activation_492 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_492[0][0
#  )                                                                  ]']
#
#  conv2d_490 (Conv2D)         (None, 7, 7, 48)             13824     ['mixed1[0][0]']
#
#  conv2d_493 (Conv2D)         (None, 7, 7, 96)             55296     ['activation_492[0][0]']
#
#  batch_normalization_490 (B  (None, 7, 7, 48)             144       ['conv2d_490[0][0]']
#  atchNormalization)
#
#  batch_normalization_493 (B  (None, 7, 7, 96)             288       ['conv2d_493[0][0]']
#  atchNormalization)
#
#  activation_490 (Activation  (None, 7, 7, 48)             0         ['batch_normalization_490[0][0
#  )                                                                  ]']
#
#  activation_493 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_493[0][0
#  )                                                                  ]']
#
#  average_pooling2d_47 (Aver  (None, 7, 7, 288)            0         ['mixed1[0][0]']
#  agePooling2D)
#
#  conv2d_489 (Conv2D)         (None, 7, 7, 64)             18432     ['mixed1[0][0]']
#
#  conv2d_491 (Conv2D)         (None, 7, 7, 64)             76800     ['activation_490[0][0]']
#
#  conv2d_494 (Conv2D)         (None, 7, 7, 96)             82944     ['activation_493[0][0]']
#
#  conv2d_495 (Conv2D)         (None, 7, 7, 64)             18432     ['average_pooling2d_47[0][0]']
#
#  batch_normalization_489 (B  (None, 7, 7, 64)             192       ['conv2d_489[0][0]']
#  atchNormalization)
#
#  batch_normalization_491 (B  (None, 7, 7, 64)             192       ['conv2d_491[0][0]']
#  atchNormalization)
#
#  batch_normalization_494 (B  (None, 7, 7, 96)             288       ['conv2d_494[0][0]']
#  atchNormalization)
#
#  batch_normalization_495 (B  (None, 7, 7, 64)             192       ['conv2d_495[0][0]']
#  atchNormalization)
#
#  activation_489 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_489[0][0
#  )                                                                  ]']
#
#  activation_491 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_491[0][0
#  )                                                                  ]']
#
#  activation_494 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_494[0][0
#  )                                                                  ]']
#
#  activation_495 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_495[0][0
#  )                                                                  ]']
#
#  mixed2 (Concatenate)        (None, 7, 7, 288)            0         ['activation_489[0][0]',
#                                                                      'activation_491[0][0]',
#                                                                      'activation_494[0][0]',
#                                                                      'activation_495[0][0]']
#
#  conv2d_497 (Conv2D)         (None, 7, 7, 64)             18432     ['mixed2[0][0]']
#
#  batch_normalization_497 (B  (None, 7, 7, 64)             192       ['conv2d_497[0][0]']
#  atchNormalization)
#
#  activation_497 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_497[0][0
#  )                                                                  ]']
#
#  conv2d_498 (Conv2D)         (None, 7, 7, 96)             55296     ['activation_497[0][0]']
#
#  batch_normalization_498 (B  (None, 7, 7, 96)             288       ['conv2d_498[0][0]']
#  atchNormalization)
#
#  activation_498 (Activation  (None, 7, 7, 96)             0         ['batch_normalization_498[0][0
#  )                                                                  ]']
#
#  conv2d_496 (Conv2D)         (None, 3, 3, 384)            995328    ['mixed2[0][0]']
#
#  conv2d_499 (Conv2D)         (None, 3, 3, 96)             82944     ['activation_498[0][0]']
#
#  batch_normalization_496 (B  (None, 3, 3, 384)            1152      ['conv2d_496[0][0]']
#  atchNormalization)
#
#  batch_normalization_499 (B  (None, 3, 3, 96)             288       ['conv2d_499[0][0]']
#  atchNormalization)
#
#  activation_496 (Activation  (None, 3, 3, 384)            0         ['batch_normalization_496[0][0
#  )                                                                  ]']
#
#  activation_499 (Activation  (None, 3, 3, 96)             0         ['batch_normalization_499[0][0
#  )                                                                  ]']
#
#  max_pooling2d_22 (MaxPooli  (None, 3, 3, 288)            0         ['mixed2[0][0]']
#  ng2D)
#
#  mixed3 (Concatenate)        (None, 3, 3, 768)            0         ['activation_496[0][0]',
#                                                                      'activation_499[0][0]',
#                                                                      'max_pooling2d_22[0][0]']
#
#  conv2d_504 (Conv2D)         (None, 3, 3, 128)            98304     ['mixed3[0][0]']
#
#  batch_normalization_504 (B  (None, 3, 3, 128)            384       ['conv2d_504[0][0]']
#  atchNormalization)
#
#  activation_504 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_504[0][0
#  )                                                                  ]']
#
#  conv2d_505 (Conv2D)         (None, 3, 3, 128)            114688    ['activation_504[0][0]']
#
#  batch_normalization_505 (B  (None, 3, 3, 128)            384       ['conv2d_505[0][0]']
#  atchNormalization)
#
#  activation_505 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_505[0][0
#  )                                                                  ]']
#
#  conv2d_501 (Conv2D)         (None, 3, 3, 128)            98304     ['mixed3[0][0]']
#
#  conv2d_506 (Conv2D)         (None, 3, 3, 128)            114688    ['activation_505[0][0]']
#
#  batch_normalization_501 (B  (None, 3, 3, 128)            384       ['conv2d_501[0][0]']
#  atchNormalization)
#
#  batch_normalization_506 (B  (None, 3, 3, 128)            384       ['conv2d_506[0][0]']
#  atchNormalization)
#
#  activation_501 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_501[0][0
#  )                                                                  ]']
#
#  activation_506 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_506[0][0
#  )                                                                  ]']
#
#  conv2d_502 (Conv2D)         (None, 3, 3, 128)            114688    ['activation_501[0][0]']
#
#  conv2d_507 (Conv2D)         (None, 3, 3, 128)            114688    ['activation_506[0][0]']
#
#  batch_normalization_502 (B  (None, 3, 3, 128)            384       ['conv2d_502[0][0]']
#  atchNormalization)
#
#  batch_normalization_507 (B  (None, 3, 3, 128)            384       ['conv2d_507[0][0]']
#  atchNormalization)
#
#  activation_502 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_502[0][0
#  )                                                                  ]']
#
#  activation_507 (Activation  (None, 3, 3, 128)            0         ['batch_normalization_507[0][0
#  )                                                                  ]']
#
#  average_pooling2d_48 (Aver  (None, 3, 3, 768)            0         ['mixed3[0][0]']
#  agePooling2D)
#
#  conv2d_500 (Conv2D)         (None, 3, 3, 192)            147456    ['mixed3[0][0]']
#
#  conv2d_503 (Conv2D)         (None, 3, 3, 192)            172032    ['activation_502[0][0]']
#
#  conv2d_508 (Conv2D)         (None, 3, 3, 192)            172032    ['activation_507[0][0]']
#
#  conv2d_509 (Conv2D)         (None, 3, 3, 192)            147456    ['average_pooling2d_48[0][0]']
#
#  batch_normalization_500 (B  (None, 3, 3, 192)            576       ['conv2d_500[0][0]']
#  atchNormalization)
#
#  batch_normalization_503 (B  (None, 3, 3, 192)            576       ['conv2d_503[0][0]']
#  atchNormalization)
#
#  batch_normalization_508 (B  (None, 3, 3, 192)            576       ['conv2d_508[0][0]']
#  atchNormalization)
#
#  batch_normalization_509 (B  (None, 3, 3, 192)            576       ['conv2d_509[0][0]']
#  atchNormalization)
#
#  activation_500 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_500[0][0
#  )                                                                  ]']
#
#  activation_503 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_503[0][0
#  )                                                                  ]']
#
#  activation_508 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_508[0][0
#  )                                                                  ]']
#
#  activation_509 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_509[0][0
#  )                                                                  ]']
#
#  mixed4 (Concatenate)        (None, 3, 3, 768)            0         ['activation_500[0][0]',
#                                                                      'activation_503[0][0]',
#                                                                      'activation_508[0][0]',
#                                                                      'activation_509[0][0]']
#
#  conv2d_514 (Conv2D)         (None, 3, 3, 160)            122880    ['mixed4[0][0]']
#
#  batch_normalization_514 (B  (None, 3, 3, 160)            480       ['conv2d_514[0][0]']
#  atchNormalization)
#
#  activation_514 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_514[0][0
#  )                                                                  ]']
#
#  conv2d_515 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_514[0][0]']
#
#  batch_normalization_515 (B  (None, 3, 3, 160)            480       ['conv2d_515[0][0]']
#  atchNormalization)
#
#  activation_515 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_515[0][0
#  )                                                                  ]']
#
#  conv2d_511 (Conv2D)         (None, 3, 3, 160)            122880    ['mixed4[0][0]']
#
#  conv2d_516 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_515[0][0]']
#
#  batch_normalization_511 (B  (None, 3, 3, 160)            480       ['conv2d_511[0][0]']
#  atchNormalization)
#
#  batch_normalization_516 (B  (None, 3, 3, 160)            480       ['conv2d_516[0][0]']
#  atchNormalization)
#
#  activation_511 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_511[0][0
#  )                                                                  ]']
#
#  activation_516 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_516[0][0
#  )                                                                  ]']
#
#  conv2d_512 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_511[0][0]']
#
#  conv2d_517 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_516[0][0]']
#
#  batch_normalization_512 (B  (None, 3, 3, 160)            480       ['conv2d_512[0][0]']
#  atchNormalization)
#
#  batch_normalization_517 (B  (None, 3, 3, 160)            480       ['conv2d_517[0][0]']
#  atchNormalization)
#
#  activation_512 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_512[0][0
#  )                                                                  ]']
#
#  activation_517 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_517[0][0
#  )                                                                  ]']
#
#  average_pooling2d_49 (Aver  (None, 3, 3, 768)            0         ['mixed4[0][0]']
#  agePooling2D)
#
#  conv2d_510 (Conv2D)         (None, 3, 3, 192)            147456    ['mixed4[0][0]']
#
#  conv2d_513 (Conv2D)         (None, 3, 3, 192)            215040    ['activation_512[0][0]']
#
#  conv2d_518 (Conv2D)         (None, 3, 3, 192)            215040    ['activation_517[0][0]']
#
#  conv2d_519 (Conv2D)         (None, 3, 3, 192)            147456    ['average_pooling2d_49[0][0]']
#
#  batch_normalization_510 (B  (None, 3, 3, 192)            576       ['conv2d_510[0][0]']
#  atchNormalization)
#
#  batch_normalization_513 (B  (None, 3, 3, 192)            576       ['conv2d_513[0][0]']
#  atchNormalization)
#
#  batch_normalization_518 (B  (None, 3, 3, 192)            576       ['conv2d_518[0][0]']
#  atchNormalization)
#
#  batch_normalization_519 (B  (None, 3, 3, 192)            576       ['conv2d_519[0][0]']
#  atchNormalization)
#
#  activation_510 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_510[0][0
#  )                                                                  ]']
#
#  activation_513 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_513[0][0
#  )                                                                  ]']
#
#  activation_518 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_518[0][0
#  )                                                                  ]']
#
#  activation_519 (Activation  (None, 3, 3, 192)            0         ['batch_normalization_519[0][0
#  )                                                                  ]']
#
#  mixed5 (Concatenate)        (None, 3, 3, 768)            0         ['activation_510[0][0]',
#                                                                      'activation_513[0][0]',
#                                                                      'activation_518[0][0]',
#                                                                      'activation_519[0][0]']
#
#  conv2d_524 (Conv2D)         (None, 3, 3, 160)            122880    ['mixed5[0][0]']
#
#  batch_normalization_524 (B  (None, 3, 3, 160)            480       ['conv2d_524[0][0]']
#  atchNormalization)
#
#  activation_524 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_524[0][0
#  )                                                                  ]']
#
#  conv2d_525 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_524[0][0]']
#
#  batch_normalization_525 (B  (None, 3, 3, 160)            480       ['conv2d_525[0][0]']
#  atchNormalization)
#
#  activation_525 (Activation  (None, 3, 3, 160)            0         ['batch_normalization_525[0][0
#  )                                                                  ]']
#
#  conv2d_521 (Conv2D)         (None, 3, 3, 160)            122880    ['mixed5[0][0]']
#
#  conv2d_526 (Conv2D)         (None, 3, 3, 160)            179200    ['activation_525[0][0]']
#
#  batch_normalization_521 (B  (None, 3, 3, 160)            480       ['conv2d_521[0][0]']
#  atchNormalization)
#
#  batch_normalization_526 (B  (None, 3, 3, 160)            480       ['conv2d_526[0][0]']
#  atchNormalization)
#
# ...
#  )                                                                  ]']
#
#  conv2d_548 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_547[0][0]']
#
#  conv2d_549 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_547[0][0]']
#
#  conv2d_552 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_551[0][0]']
#
#  conv2d_553 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_551[0][0]']
#
#  average_pooling2d_52 (Aver  (None, 1, 1, 1280)           0         ['mixed8[0][0]']
#  agePooling2D)
#
#  conv2d_546 (Conv2D)         (None, 1, 1, 320)            409600    ['mixed8[0][0]']
#
#  batch_normalization_548 (B  (None, 1, 1, 384)            1152      ['conv2d_548[0][0]']
#  atchNormalization)
#
#  batch_normalization_549 (B  (None, 1, 1, 384)            1152      ['conv2d_549[0][0]']
#  atchNormalization)
#
#  batch_normalization_552 (B  (None, 1, 1, 384)            1152      ['conv2d_552[0][0]']
#  atchNormalization)
#
#  batch_normalization_553 (B  (None, 1, 1, 384)            1152      ['conv2d_553[0][0]']
#  atchNormalization)
#
#  conv2d_554 (Conv2D)         (None, 1, 1, 192)            245760    ['average_pooling2d_52[0][0]']
#
#  batch_normalization_546 (B  (None, 1, 1, 320)            960       ['conv2d_546[0][0]']
#  atchNormalization)
#
#  activation_548 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_548[0][0
#  )                                                                  ]']
#
#  activation_549 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_549[0][0
#  )                                                                  ]']
#
#  activation_552 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_552[0][0
#  )                                                                  ]']
#
#  activation_553 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_553[0][0
#  )                                                                  ]']
#
#  batch_normalization_554 (B  (None, 1, 1, 192)            576       ['conv2d_554[0][0]']
#  atchNormalization)
#
#  activation_546 (Activation  (None, 1, 1, 320)            0         ['batch_normalization_546[0][0
#  )                                                                  ]']
#
#  mixed9_0 (Concatenate)      (None, 1, 1, 768)            0         ['activation_548[0][0]',
#                                                                      'activation_549[0][0]']
#
#  concatenate_10 (Concatenat  (None, 1, 1, 768)            0         ['activation_552[0][0]',
#  e)                                                                  'activation_553[0][0]']
#
#  activation_554 (Activation  (None, 1, 1, 192)            0         ['batch_normalization_554[0][0
#  )                                                                  ]']
#
#  mixed9 (Concatenate)        (None, 1, 1, 2048)           0         ['activation_546[0][0]',
#                                                                      'mixed9_0[0][0]',
#                                                                      'concatenate_10[0][0]',
#                                                                      'activation_554[0][0]']
#
#  conv2d_559 (Conv2D)         (None, 1, 1, 448)            917504    ['mixed9[0][0]']
#
#  batch_normalization_559 (B  (None, 1, 1, 448)            1344      ['conv2d_559[0][0]']
#  atchNormalization)
#
#  activation_559 (Activation  (None, 1, 1, 448)            0         ['batch_normalization_559[0][0
#  )                                                                  ]']
#
#  conv2d_556 (Conv2D)         (None, 1, 1, 384)            786432    ['mixed9[0][0]']
#
#  conv2d_560 (Conv2D)         (None, 1, 1, 384)            1548288   ['activation_559[0][0]']
#
#  batch_normalization_556 (B  (None, 1, 1, 384)            1152      ['conv2d_556[0][0]']
#  atchNormalization)
#
#  batch_normalization_560 (B  (None, 1, 1, 384)            1152      ['conv2d_560[0][0]']
#  atchNormalization)
#
#  activation_556 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_556[0][0
#  )                                                                  ]']
#
#  activation_560 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_560[0][0
#  )                                                                  ]']
#
#  conv2d_557 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_556[0][0]']
#
#  conv2d_558 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_556[0][0]']
#
#  conv2d_561 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_560[0][0]']
#
#  conv2d_562 (Conv2D)         (None, 1, 1, 384)            442368    ['activation_560[0][0]']
#
#  average_pooling2d_53 (Aver  (None, 1, 1, 2048)           0         ['mixed9[0][0]']
#  agePooling2D)
#
#  conv2d_555 (Conv2D)         (None, 1, 1, 320)            655360    ['mixed9[0][0]']
#
#  batch_normalization_557 (B  (None, 1, 1, 384)            1152      ['conv2d_557[0][0]']
#  atchNormalization)
#
#  batch_normalization_558 (B  (None, 1, 1, 384)            1152      ['conv2d_558[0][0]']
#  atchNormalization)
#
#  batch_normalization_561 (B  (None, 1, 1, 384)            1152      ['conv2d_561[0][0]']
#  atchNormalization)
#
#  batch_normalization_562 (B  (None, 1, 1, 384)            1152      ['conv2d_562[0][0]']
#  atchNormalization)
#
#  conv2d_563 (Conv2D)         (None, 1, 1, 192)            393216    ['average_pooling2d_53[0][0]']
#
#  batch_normalization_555 (B  (None, 1, 1, 320)            960       ['conv2d_555[0][0]']
#  atchNormalization)
#
#  activation_557 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_557[0][0
#  )                                                                  ]']
#
#  activation_558 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_558[0][0
#  )                                                                  ]']
#
#  activation_561 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_561[0][0
#  )                                                                  ]']
#
#  activation_562 (Activation  (None, 1, 1, 384)            0         ['batch_normalization_562[0][0
#  )                                                                  ]']
#
#  batch_normalization_563 (B  (None, 1, 1, 192)            576       ['conv2d_563[0][0]']
#  atchNormalization)
#
#  activation_555 (Activation  (None, 1, 1, 320)            0         ['batch_normalization_555[0][0
#  )                                                                  ]']
#
#  mixed9_1 (Concatenate)      (None, 1, 1, 768)            0         ['activation_557[0][0]',
#                                                                      'activation_558[0][0]']
#
#  concatenate_11 (Concatenat  (None, 1, 1, 768)            0         ['activation_561[0][0]',
#  e)                                                                  'activation_562[0][0]']
#
#  activation_563 (Activation  (None, 1, 1, 192)            0         ['batch_normalization_563[0][0
#  )                                                                  ]']
#
#  mixed10 (Concatenate)       (None, 1, 1, 2048)           0         ['activation_555[0][0]',
#                                                                      'mixed9_1[0][0]',
#                                                                      'concatenate_11[0][0]',
#                                                                      'activation_563[0][0]']
#
#  flatten_14 (Flatten)        (None, 2048)                 0         ['mixed10[0][0]']
#
#  dense_28 (Dense)            (None, 2048)                 4196352   ['flatten_14[0][0]']
#
#  dropout_14 (Dropout)        (None, 2048)                 0         ['dense_28[0][0]']
#
#  dense_29 (Dense)            (None, 6)                    12294     ['dropout_14[0][0]']
#
# ==================================================================================================
# Total params: 26011430 (99.23 MB)
# Trainable params: 25976998 (99.09 MB)
# Non-trainable params: 34432 (134.50 KB)
# __________________________________________________________________________________________________

# %%
from time import time
for batch_size in [32,64,96,128]:
    t_zero = time()
    model = prepare_model()
    history = model.fit(X_train_s, 
                        y_train_s,
                        batch_size = batch_size,
                        validation_split=0.2,
                        epochs=1,)
    tiempo = round(time() - t_zero, 3)
    print(f"batch_size: {batch_size}, num_steps: {len(X_train)/batch_size}, tiempo 1 epoca: {tiempo}, tiempo 20 épocas: {tiempo * 20}")
# Out:
# 351/351 [==============================] - 144s 368ms/step - loss: 1.4439 - acc: 0.4903 - val_loss: 1.9053 - val_acc: 0.3484
# batch_size: 32, num_steps: 438.5625, tiempo 1 epoca: 153.83, tiempo 20 épocas: 3076.6000000000004
# 176/176 [==============================] - 105s 518ms/step - loss: 1.5434 - acc: 0.4738 - val_loss: 662.0442 - val_acc: 0.2590
# batch_size: 64, num_steps: 219.28125, tiempo 1 epoca: 108.244, tiempo 20 épocas: 2164.88
# 117/117 [==============================] - 97s 684ms/step - loss: 1.4037 - acc: 0.4825 - val_loss: 3690.0498 - val_acc: 0.1724
# batch_size: 96, num_steps: 146.1875, tiempo 1 epoca: 101.26, tiempo 20 épocas: 2025.2
# 88/88 [==============================] - 87s 838ms/step - loss: 1.1640 - acc: 0.5611 - val_loss: 135.6063 - val_acc: 0.1721
# batch_size: 128, num_steps: 109.640625, tiempo 1 epoca: 88.032, tiempo 20 épocas: 1760.6399999999999

# %% [markdown]
# *Mantenemos el batch_size en 128*

# %% [markdown]
# *Lanzamos el fine-tuning y a esperar*

# %%
t_zero = time()
model = prepare_model()
history = model.fit(X_train_s, 
                    y_train_s,
                    batch_size = batch_size,
                    validation_split=0.2,
                    epochs=40,
                    callbacks = [earlyS])
tiempo = round(time() - t_zero, 3)
# Out:
# Epoch 1/40
# 88/88 [==============================] - 86s 786ms/step - loss: 1.2511 - acc: 0.5771 - val_loss: 676.7662 - val_acc: 0.1760
# Epoch 2/40
# 88/88 [==============================] - 69s 788ms/step - loss: 0.8845 - acc: 0.6496 - val_loss: 1.1461 - val_acc: 0.5543
# Epoch 3/40
# 88/88 [==============================] - 71s 806ms/step - loss: 0.8754 - acc: 0.6972 - val_loss: 2.3162 - val_acc: 0.2590
# Epoch 4/40
# 88/88 [==============================] - 75s 853ms/step - loss: 1.3883 - acc: 0.5530 - val_loss: 7574.2061 - val_acc: 0.1678
# Epoch 5/40
# 88/88 [==============================] - 80s 906ms/step - loss: 1.3435 - acc: 0.4780 - val_loss: 39.2353 - val_acc: 0.2868
# Epoch 6/40
# 88/88 [==============================] - 78s 891ms/step - loss: 1.0187 - acc: 0.6003 - val_loss: 1.1853 - val_acc: 0.4984
# Epoch 7/40
# 88/88 [==============================] - 79s 892ms/step - loss: 0.8983 - acc: 0.6519 - val_loss: 1.0977 - val_acc: 0.5924
# Epoch 8/40
# 88/88 [==============================] - 85s 970ms/step - loss: 0.8259 - acc: 0.6859 - val_loss: 1.0658 - val_acc: 0.5597
# Epoch 9/40
# 88/88 [==============================] - 85s 970ms/step - loss: 0.7606 - acc: 0.7125 - val_loss: 0.8179 - val_acc: 0.7040
# Epoch 10/40
# 88/88 [==============================] - 81s 926ms/step - loss: 0.7038 - acc: 0.7439 - val_loss: 0.8098 - val_acc: 0.7043
# Epoch 11/40
# 88/88 [==============================] - 79s 899ms/step - loss: 0.6448 - acc: 0.7715 - val_loss: 1.8274 - val_acc: 0.6819
# Epoch 12/40
# 88/88 [==============================] - 80s 914ms/step - loss: 0.5906 - acc: 0.7904 - val_loss: 0.7793 - val_acc: 0.7264
# Epoch 13/40
# 88/88 [==============================] - 78s 884ms/step - loss: 0.5610 - acc: 0.8033 - val_loss: 0.7369 - val_acc: 0.7403
# Epoch 14/40
# 88/88 [==============================] - 79s 900ms/step - loss: 0.5359 - acc: 0.8119 - val_loss: 0.7830 - val_acc: 0.7481
# Epoch 15/40
# 88/88 [==============================] - 77s 873ms/step - loss: 0.5077 - acc: 0.8239 - val_loss: 0.8336 - val_acc: 0.7150
# Epoch 16/40
# 88/88 [==============================] - 73s 826ms/step - loss: 0.4761 - acc: 0.8321 - val_loss: 1.0128 - val_acc: 0.6587
# Epoch 17/40
# 88/88 [==============================] - 72s 824ms/step - loss: 0.4622 - acc: 0.8395 - val_loss: 0.8572 - val_acc: 0.7349
# Epoch 18/40
# 88/88 [==============================] - 72s 816ms/step - loss: 0.4044 - acc: 0.8620 - val_loss: 0.7304 - val_acc: 0.7763
# Epoch 19/40
# 88/88 [==============================] - 72s 817ms/step - loss: 0.4035 - acc: 0.8637 - val_loss: 0.7061 - val_acc: 0.7748
# Epoch 20/40
# 88/88 [==============================] - 74s 842ms/step - loss: 0.3558 - acc: 0.8790 - val_loss: 0.7430 - val_acc: 0.7663
# Epoch 21/40
# 88/88 [==============================] - 75s 848ms/step - loss: 0.3444 - acc: 0.8793 - val_loss: 0.6077 - val_acc: 0.8005
# Epoch 22/40
# 88/88 [==============================] - 78s 883ms/step - loss: 0.3299 - acc: 0.8866 - val_loss: 0.7603 - val_acc: 0.7862
# Epoch 23/40
# 88/88 [==============================] - 79s 903ms/step - loss: 0.3385 - acc: 0.8860 - val_loss: 0.7133 - val_acc: 0.7759
# Epoch 24/40
# 88/88 [==============================] - 79s 897ms/step - loss: 0.3098 - acc: 0.8945 - val_loss: 0.7147 - val_acc: 0.7756
# Epoch 25/40
# 88/88 [==============================] - 80s 910ms/step - loss: 0.2781 - acc: 0.9051 - val_loss: 0.6454 - val_acc: 0.8026
# Epoch 26/40
# 88/88 [==============================] - 82s 928ms/step - loss: 0.2807 - acc: 0.9007 - val_loss: 0.6217 - val_acc: 0.8115
# Epoch 27/40
# 88/88 [==============================] - 78s 888ms/step - loss: 0.2641 - acc: 0.9097 - val_loss: 0.9639 - val_acc: 0.7649
# Epoch 28/40
# 88/88 [==============================] - 79s 894ms/step - loss: 0.2214 - acc: 0.9236 - val_loss: 0.8308 - val_acc: 0.7674
# Epoch 29/40
# 88/88 [==============================] - 82s 931ms/step - loss: 0.2208 - acc: 0.9264 - val_loss: 1.2092 - val_acc: 0.6943
# Epoch 30/40
# 88/88 [==============================] - 85s 966ms/step - loss: 0.2111 - acc: 0.9267 - val_loss: 0.8315 - val_acc: 0.7820
# Epoch 31/40
# 88/88 [==============================] - 81s 924ms/step - loss: 0.3028 - acc: 0.8965 - val_loss: 2.3381 - val_acc: 0.7677

# %%
model.evaluate(X_test,y_test_num)
# Out:
# 94/94 [==============================] - 8s 81ms/step - loss: 0.5891 - acc: 0.8063
# [0.589076042175293, 0.8063333630561829]

# %% [markdown]
# *Bueno, un 80%, 4 pp. mejor que el modelo con dos capas convolucionales,... ¿merece la pena el esfuerzo?*

# %%
y_pred = [ np.argmax(prediction) for prediction in model.predict(X_test)]
# Out:
# 94/94 [==============================] - 12s 83ms/step

# %%
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
inverse_map = {valor:clave for clave,valor in mapa.items()}
y_test_labels = [inverse_map[y] for y in y_test_num]
y_pred_labels = [inverse_map[y] for y in y_pred]
print(classification_report(y_test_labels, y_pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#    buildings       0.80      0.78      0.79       437
#       forest       0.92      0.94      0.93       474
#      glacier       0.82      0.69      0.75       553
#     mountain       0.75      0.80      0.78       525
#          sea       0.71      0.88      0.79       510
#       street       0.88      0.76      0.82       501
#
#     accuracy                           0.81      3000
#    macro avg       0.81      0.81      0.81      3000
# weighted avg       0.81      0.81      0.81      3000

# %%
ConfusionMatrixDisplay.from_predictions(y_test_labels, y_pred_labels, normalize="true")

# %% [markdown]
# *El modelo completo ha mejorado en las que era peor el anterior pero a costa de empeorar en edificios y calles que ahora se confunden no solo entre ellos sino que un poco con todos.*

# %% [markdown]
# *El modelo fine-tuneado mejora en casi todo al modelo inicial, salvo en la detección de street y ligeramente en las montañas*

# %% [markdown]
# ### EXTRA

# %% [markdown]
# *Vamos a repetir la parte de trasnfer learning pero utilizando aumentado de imágenes a ver si mejoramos algo más*

# %%
ficheros = []
clases = []
for directorio in os.listdir(TRAIN_PATH):
    clase = directorio
    ficher = [TRAIN_PATH + directorio + "/" + fichero for fichero in os.listdir(TRAIN_PATH + directorio)]
    clases += [clase for fichero in ficher]
    ficheros += ficher
train_augmented = pd.DataFrame({"filename": ficheros,"category": clases})
train_augmented.head(10)
# Out:
#                                filename   category
# 0      ./data/seg_train/buildings/0.jpg  buildings
# 1  ./data/seg_train/buildings/10006.jpg  buildings
# 2   ./data/seg_train/buildings/1001.jpg  buildings
# 3  ./data/seg_train/buildings/10014.jpg  buildings
# 4  ./data/seg_train/buildings/10018.jpg  buildings
# 5  ./data/seg_train/buildings/10029.jpg  buildings
# 6  ./data/seg_train/buildings/10032.jpg  buildings
# 7  ./data/seg_train/buildings/10056.jpg  buildings
# 8   ./data/seg_train/buildings/1009.jpg  buildings
# 9  ./data/seg_train/buildings/10113.jpg  buildings

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rotation_range=15, # Angulo de rotación
    # Escalado, ya nos escala las imágenes
    shear_range=0.1, # Inclina las imágenes, no es giro es inclinación como hacerlas "cursivas"
    zoom_range=0.2, # Zoom
    horizontal_flip=True, # giro horizontal o especular
    width_shift_range=0.1, # Desplazamiento horizontal de los pixeles
    height_shift_range=0.1 # Desplazamiento vertical de los píxeles
)

# %%
train_df, validate_df = train_test_split(train_augmented,
                                         test_size=0.20,
                                         random_state=42)

# %%
train_df = train_df.reset_index(drop=True)
validate_df = validate_df.reset_index(drop=True)

# %%
train_generator = train_datagen.flow_from_dataframe(
    train_df, 
    x_col='filename',
    y_col='category',
    target_size=(IMG_WIDTH, IMG_HEIGHT),
    class_mode='sparse', # Porque es binaria, si fuera multiclase y en un sólo valor -> "sparse" (otras configuraciones, ver la documentación)
    batch_size= batch_size
)
# Out:
# Found 11227 validated image filenames belonging to 6 classes.

# %%
validation_datagen = ImageDataGenerator(rescale=1./255) # Solo vamos a reescalar
validation_generator = validation_datagen.flow_from_dataframe(
    validate_df, 
    x_col='filename',
    y_col='category',
    target_size=(IMG_WIDTH, IMG_HEIGHT),
    class_mode='sparse',
    batch_size= batch_size
)
# Out:
# Found 2807 validated image filenames belonging to 6 classes.

# %%
 from 
# Cargamos el modelo pre-entrenado
base_model = InceptionV3(include_top=False, weights='imagenet', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3))

# Congelamos sus capas
for layer in base_model.layers:
    layer.trainable = False


# Capa de flatenizado de la salida del modelo base
def prepare_model(base_model = base_model): # Lo creamos así para poder reinicializarlo en cada reentrenamiento en ejercicios posteriores
    x = keras.layers.Flatten()(base_model.output)
    
    # Tantas unidades como el flatten de la salida de Inception
    x = keras.layers.Dense(2048, activation='relu')(x)
    x = keras.layers.Dropout(rate = 0.25)(x)

    
    # Capa final de salida con 6 neuronas (una por clase) y activación softmax
    x = keras.layers.Dense(6, activation='softmax')(x)
    
    model = keras.Model(base_model.input, x)
    model.compile(optimizer = "adam", loss = 'sparse_categorical_crossentropy', metrics = ['acc'])
    return model
# Observamos la arquitectura del modelo
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Cargamos el modelo pre-entrenado
# ----> 2 base_model = InceptionV3(include_top=False, weights='imagenet', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3))
#       4 # Congelamos sus capas
#       5 for layer in base_model.layers:
#
# NameError: name 'InceptionV3' is not defined

# %%
model = prepare_model()
history = model.fit(
    train_generator, 
    epochs= 40,
    validation_data=validation_generator,
    callbacks= earlyS
)
# Out:
# Epoch 1/40
# 88/88 [==============================] - 112s 1s/step - loss: 0.9341 - acc: 0.6634 - val_loss: 0.6794 - val_acc: 0.7467
# Epoch 2/40
# 88/88 [==============================] - 35s 392ms/step - loss: 0.7067 - acc: 0.7380 - val_loss: 0.6873 - val_acc: 0.7367
# Epoch 3/40
# 88/88 [==============================] - 35s 399ms/step - loss: 0.6708 - acc: 0.7472 - val_loss: 0.6732 - val_acc: 0.7431
# Epoch 4/40
# 88/88 [==============================] - 36s 403ms/step - loss: 0.6577 - acc: 0.7561 - val_loss: 0.6340 - val_acc: 0.7617
# Epoch 5/40
# 88/88 [==============================] - 36s 403ms/step - loss: 0.6355 - acc: 0.7653 - val_loss: 0.6124 - val_acc: 0.7667
# Epoch 6/40
# 88/88 [==============================] - 36s 406ms/step - loss: 0.6218 - acc: 0.7657 - val_loss: 0.6103 - val_acc: 0.7631
# Epoch 7/40
# 88/88 [==============================] - 35s 403ms/step - loss: 0.6040 - acc: 0.7734 - val_loss: 0.6149 - val_acc: 0.7695
# Epoch 8/40
# 88/88 [==============================] - 36s 404ms/step - loss: 0.5827 - acc: 0.7831 - val_loss: 0.6068 - val_acc: 0.7709
# Epoch 9/40
# 88/88 [==============================] - 35s 399ms/step - loss: 0.5905 - acc: 0.7746 - val_loss: 0.6111 - val_acc: 0.7731
# Epoch 10/40
# 88/88 [==============================] - 35s 401ms/step - loss: 0.5793 - acc: 0.7835 - val_loss: 0.6012 - val_acc: 0.7816
# Epoch 11/40
# 88/88 [==============================] - 35s 401ms/step - loss: 0.5626 - acc: 0.7912 - val_loss: 0.6015 - val_acc: 0.7734
# Epoch 12/40
# 88/88 [==============================] - 35s 399ms/step - loss: 0.5718 - acc: 0.7862 - val_loss: 0.5907 - val_acc: 0.7795
# Epoch 13/40
# 88/88 [==============================] - 35s 402ms/step - loss: 0.5489 - acc: 0.7968 - val_loss: 0.5863 - val_acc: 0.7745
# Epoch 14/40
# 88/88 [==============================] - 36s 408ms/step - loss: 0.5458 - acc: 0.7977 - val_loss: 0.5739 - val_acc: 0.7877
# Epoch 15/40
# 88/88 [==============================] - 35s 403ms/step - loss: 0.5412 - acc: 0.7971 - val_loss: 0.5900 - val_acc: 0.7752
# Epoch 16/40
# 88/88 [==============================] - 35s 401ms/step - loss: 0.5412 - acc: 0.7941 - val_loss: 0.5812 - val_acc: 0.7784
# Epoch 17/40
# 88/88 [==============================] - 36s 406ms/step - loss: 0.5361 - acc: 0.7962 - val_loss: 0.5753 - val_acc: 0.7841
# Epoch 18/40
# 88/88 [==============================] - 35s 401ms/step - loss: 0.5141 - acc: 0.8107 - val_loss: 0.5784 - val_acc: 0.7766
# Epoch 19/40
# 88/88 [==============================] - 36s 406ms/step - loss: 0.5270 - acc: 0.8017 - val_loss: 0.5747 - val_acc: 0.7838
# Epoch 20/40
# 88/88 [==============================] - 37s 420ms/step - loss: 0.5215 - acc: 0.8030 - val_loss: 0.5748 - val_acc: 0.7870
# Epoch 21/40
# 88/88 [==============================] - 39s 438ms/step - loss: 0.5094 - acc: 0.8056 - val_loss: 0.5704 - val_acc: 0.7848
# Epoch 22/40
# 88/88 [==============================] - 36s 411ms/step - loss: 0.4986 - acc: 0.8081 - val_loss: 0.5825 - val_acc: 0.7870
# Epoch 23/40
# 88/88 [==============================] - 37s 421ms/step - loss: 0.5059 - acc: 0.8096 - val_loss: 0.5757 - val_acc: 0.7838
# Epoch 24/40
# 88/88 [==============================] - 37s 419ms/step - loss: 0.4929 - acc: 0.8136 - val_loss: 0.5814 - val_acc: 0.7802
# Epoch 25/40
# 88/88 [==============================] - 35s 402ms/step - loss: 0.5035 - acc: 0.8095 - val_loss: 0.5698 - val_acc: 0.7862
# Epoch 26/40
# 88/88 [==============================] - 37s 417ms/step - loss: 0.4976 - acc: 0.8087 - val_loss: 0.5667 - val_acc: 0.7927
# Epoch 27/40
# 88/88 [==============================] - 36s 405ms/step - loss: 0.4899 - acc: 0.8178 - val_loss: 0.5658 - val_acc: 0.7862
# Epoch 28/40
# 88/88 [==============================] - 36s 406ms/step - loss: 0.4910 - acc: 0.8180 - val_loss: 0.5740 - val_acc: 0.7937
# Epoch 29/40
# 88/88 [==============================] - 35s 401ms/step - loss: 0.4845 - acc: 0.8188 - val_loss: 0.5828 - val_acc: 0.7855
# Epoch 30/40
# 88/88 [==============================] - 35s 399ms/step - loss: 0.4720 - acc: 0.8216 - val_loss: 0.5800 - val_acc: 0.7852
# Epoch 31/40
# 88/88 [==============================] - 36s 404ms/step - loss: 0.4772 - acc: 0.8206 - val_loss: 0.5707 - val_acc: 0.7816
# Epoch 32/40
# 88/88 [==============================] - 36s 413ms/step - loss: 0.4711 - acc: 0.8222 - val_loss: 0.5570 - val_acc: 0.7944
# Epoch 33/40
# 88/88 [==============================] - 36s 405ms/step - loss: 0.4641 - acc: 0.8268 - val_loss: 0.5740 - val_acc: 0.7941
# Epoch 34/40
# 88/88 [==============================] - 35s 401ms/step - loss: 0.4695 - acc: 0.8247 - val_loss: 0.5953 - val_acc: 0.7791
# Epoch 35/40
# 88/88 [==============================] - 35s 402ms/step - loss: 0.4646 - acc: 0.8234 - val_loss: 0.5895 - val_acc: 0.7873
# Epoch 36/40
# 88/88 [==============================] - 36s 403ms/step - loss: 0.4553 - acc: 0.8267 - val_loss: 0.5824 - val_acc: 0.7880
# Epoch 37/40
# 88/88 [==============================] - 36s 406ms/step - loss: 0.4803 - acc: 0.8186 - val_loss: 0.5703 - val_acc: 0.7873
# Epoch 38/40
# 88/88 [==============================] - 36s 409ms/step - loss: 0.4542 - acc: 0.8283 - val_loss: 0.5903 - val_acc: 0.7791
# Epoch 39/40
# 88/88 [==============================] - 35s 401ms/step - loss: 0.4511 - acc: 0.8332 - val_loss: 0.5823 - val_acc: 0.7870
# Epoch 40/40
# 88/88 [==============================] - 36s 406ms/step - loss: 0.4412 - acc: 0.8369 - val_loss: 0.5607 - val_acc: 0.7909

# %%
model.evaluate(X_test,y_test_num)
# Out:
# 94/94 [==============================] - 8s 68ms/step - loss: 0.5597 - acc: 0.7973
# [0.5596623420715332, 0.7973333597183228]

# %%
[prompt,imagen] -> Modelo procesa prompt -Modela Imagen modelo
